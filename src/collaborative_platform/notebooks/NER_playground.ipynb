# %% [markdown]
# # PROVIDEDH Collaborative platform
# ## Jupyter notebook

# %%
from apps.files_management.models import File, FileVersion, Directory
from apps.projects.models import Project

# %%
from django.db.models import Q

# %%
from lxml import etree as et
from lxml.etree import Element
import re

# %%
import nltk
import spacy
import en_core_web_md
sp_nlp_en = en_core_web_md.load()

# %% [markdown]
# ## 1 File retrieval

# %%
namespaces = {'tei': 'http://www.tei-c.org/ns/1.0', 'xml': 'http://www.w3.org/XML/1998/namespace'}

# %%
project = Project.objects.get(title__exact='ner')
files_query = Q(project=project)

# %%
files = File.objects.filter(files_query)

# %%
f = files[0]

# %%
v = f.versions.all()[1]

# %%
v
# Out:
# <FileVersion: FileVersion object (280)>

# %%
f.name
# Out:
# 'dep_809001r001_tei_(original_normalized_depositions_marked_persons).xml'

# %% [markdown]
# ## 2 File processing

# %%
f = files[0]
f_download = f.download()
f_content = f_download.getvalue().decode('UTF-8')

# %%
f_et = et.XML(f_content)

body = f_et.xpath('.//tei:body', namespaces=namespaces)[0]

body_text = body.xpath('.//text()')

withtextnodes = lambda x: len(x.xpath('text()')) > 0
notemptyline = lambda text: len(text.strip()) > 0
withnotemptylines = lambda node: any(map(notemptyline, node.xpath('text()')))

nodes_filtered = filter(withnotemptylines, filter(withtextnodes, body.iter()))
text_nodes = list(map(lambda x: list(filter(notemptyline, x.xpath('text()'))), nodes_filtered))

body_text_filtered = ' '.join(map(lambda x: ' '.join(x), text_nodes))

# %% [markdown]
# ## 3 Text tagging

# %% [markdown]
# ### spacy en_core_web_md

# %%
print(body_text_filtered)
# Out:
# William Aldrich William Hitchcock Roger Puttock John Sterne John Watson Dublin
#                     I   Doctor in Diuinity in obedience to his maiesties Comission requireing an accompt of
#                     the losses of his lojall subjects wherein they suffered by the present  , &
#                     requireing an accompt of what traiterous words, proiects or Actions were done, said, or plotted by
#                     the actors, or by the Abettors in that rebellion: Doe make and give in this following report of the
#                     premises to the best of my knowledge vpon oath: vizt, As for the present  Howsoever the
#                     firste breaking out of this fire into a flame began first on the   yet was it
#                     smokeing (as may well be conjectured, for many yeres before: God haveing given us many and apparant
#                     groundes for the discouery of it, had they bin duly considered on, or duly prosecuted to a
#                     discouery, Of which kynd wee fynd theis former following particulars First that about  since, amongst many bookes brought into the   from forraine parts, & seazed
#                     vpon by the reuerend Bishop of that Sea as prohibited (being therevnto authorized by the state) one
#                     had a written addition to the first part which was printed, conteyneing a discourse of the friers of
#                     the Augustine order, somtimes seated in the : But by reason of the times,
#
#                     at that present Resident (as that writing imported) in the  , That
#                     whylest it flourished at , it was protected, & largely provided for by the then   Since whose expulsion out of Ireland, that Convent was alsoe decayed & driven to those
#                     distresses it did for the present vndergoe, but that within   (This is as I remember, the time
#                     limitted) Ireland should fynd, he had a sonne inheriteing his fathers virtues Whoe should restore
#                     that kingdome to its former liberty, & that Convent to its first lustre or words to that effect,
#                     This was related vnto mee by that zealous & learned prelate  , now Bishop of Limrick
#                     whoe sawe & read the said passages Purposeing (as his Lordship tould mee) to send that booke to
#                     the   to be taken into further consideracion: 2 Hereunto was added a
#                     second passage about the same time at Limrick aforesaid, Where a popish preist gave out That within
#   there should not be a protestant in , or words to that purpose, with some other
#                     materiall Circumstances which I doe not now remember, yet all soe concurring with the former, (or
#                     the first with this) which precede I know not but being about one tyme) That it was thought fitting
#                     to be considered of, The said preist being sent to the Lords at  & he committed to the
#                     Castle  The
#                     75
#
#                         Exw 137
#                      Henry Jones Rebellion in Ireland  Rebellion xxiijth of October 1641  3 or 4
#                     yeres Citty of Limrick  towne of Armagh in Vlster
#                         and
#                      Citty of Limrick in Mounster  Armaghe Erle of
#                     Tirone 3 yeres Doctor Webb Lord President of Mounster                     3 yeres  Ireland  Dublin
#                         264
#                      3 The third did agree with the twoe former, and fell out about the same time in the  Where one Walter Nugent of Rathaspick in the said County eldest sonn to Walter
#                     Nugent Esquire (a man of great fortunes) vpbraiding an Irish protestant, whoe was parrish Clearke of
#                     Rathaspick aforesaid) with his Religion, & both speakeing Latine, the said Nugent vttered theis
#                     words. Infra tres annos venient tempus & potentia in Hibernia quando tu longe (Likely meaneing,
#                     diu) pendebis in cruce propter diabolicam vestram religionem; The party to which this was spoken,
#                     fearing the power of the man durst not speake of it, only in private, yet being called vpon &
#                     examined Juridically vpon his oath, he deposed theis wordes & being demanded whether the words
#                     were in   or in  , The first importing an Invasion, the other an insurrection at
#                     home, he deposed the later, (haveing tyme given him to consider of it) Theis Examinacions were sent
#                     to Sir  , Nugent was sent for & Committed to the Castle, & remained in long
#                     durance but afterwards dismissed &c 4 Hereunto was added a fowrth, about the same time nere
#                     the Naas about 12 miles from  , Where a papist preist (newly arrived out of fflaunders, did
#                     make his addresse to the then lord Deputy, & informed his lordship of an intercourse of letters
#                     betweene the   with others in fflaunders, and the Popish Primate of Armaghe, Rely,
#                     concerning an invasion within a short time intended vpon  , The said preiste offering, (soe
#                     his person might be secured) to direct such as should be therevnto appointed to the place where the
#                     said Letters lay in the Custodie of the said Relye, Rely was therevpon sent for, together with the
#                     popish Vicar generall of Armaghe (as I remember it; Both were Comitted to the
#                     , but soone after released, & the Informer dismissed with x li. and a suite of Clothes, or some
#                     such Reward  Herevnto
#                  County of
#                     Meath in Leinster  Hiberniam Hibernia George Radcliff Dublin Erle of Tirone Ireland Castle
#
#                         of Dublin
#                      Hereunto may be further added, (yet not soe plaine as the former) That about the same time the
#                       did ride disguised through
#
#                     Munster, pretending to satisfy his curiosity in the knowledg of places & persons, Hee not being
#                     discouered vntill his returne att the Birr, Where having offered himself to be bound for one in his
#                     Company, he writt himself in his owne stile, Being loath to leave vnder his hand a testemony of his
#                     disguised person and assumed name To discend nowe from the antecedents of this treason to the
#                     falleing in therevpon, and lastly to the Consequents, & what thereby hath bin intended,
#                     (supposeing it to succeed) & that it attained the desired effect, which by them was not doubted
#                     of And first for the entrance thereinto: Howsoeuer that the ground worke were long since laid, yet
#                     would they not have it soe to seeme, But newe occasion must be fownd as the sole cawse of their
#                     breaking out, This being intended for satisfieing the mindes of such of their owne as have not
#                     hitherto been acquainted with the depth and mistery of this iniquitie, that they might
#
#                     stand amazed at the suddennes of the vndertakeing, or stand off from Joineing with them in the worst
#                     part of their designes, it beinge an apparant Rebellion, The fittest meanes for this must have beene
#                     by casting aspersions on the present gouerment, which (if longer tollerated) would prove extreamely
#                     dangerous not only to their religion but their lives & posterity: For effecting whereof reports
#                     were cast out, That in the , the cutting off of all the papists in Ireland, of
#                     what degree soever, was concluded vpon, The execution of that Resolution being comitted to the
#                     Counsel  The Lords (said they) had laide downe a day for this work, being the xxiijth
#                     day of November then next following & now last past or thereabouts, ffor the better more secure,
#                     & more secrett manageing of this pretended plott Such of the popish nobility & gentrie of
#                     both howses as appeared in   should be secured, & for the drawing together
#                     the rest (amongst other pretences) this alledged to be one, That his  maiesties
#                     76
#                  Lord Baron of Dunsany
#                         all
#
#                         not
#                       Parliament of England l in Ireland: Parliament at Dublin
#                         265
#                      maiesties rents were purposely omytted, & not called vpon in Ester terme with that
#                     earnestnes as fomerly, and that such as made default should be sommoned to appeare at Michelmas
#                     tearme at Dublin, and there surprised; Such of them as were then in the Cuntrie (wanting their
#                     heads, being easily cutt off:) They say that this pretended plott was (I know not how) discouered to
#                     them: Soe that for the safety of their lives & profession they were enforced to stand vpon their
#                     guard, & to counterworke that daie of the  , laid for their distruction by
#                     their declareing themselves in Armes on the xxiijth of October (a moneth before) The serious part of
#                     this discourse was related to mee, by a frier intimate in their  , & by a preist (a
#                     popish Vicar generall), thereby to give mee satisfaccion, and to iustify their proseedings; Which
#                     names I doe for the present forbeare, in respect of his maiesties service:  By others alsoe I
#                     was enformed, That this plott was mainely intended in that Session of   next after the Erle
#                     of Straffords beheading, & the manner concluded vpon in the popish private meetings, which were
#                     then observed to be frequent, & by some suspected might proue dangerous; And that for discouery
#                     of what proportion of Armes & Amunition our store of Dublin afforded (Itt being by some
#                     suspected that most was carried before to Carickfergus, One of the popish faction in the howse
#
#                     of Commons putt one of the protestant members to move & enforme That some of the  s men had cast out some threatening wordes against the parliament in revenge of his Lord
#                     which could not be conceaved to end in lesse then a blowing vp of the whole howses of Paliament, the
#                     store lying vnder them, Wherevpon a Commi
#
#                     of both howses (many of them prime papists) were appointed to make search in odd Corners, Amongst
#                     theis, the   was one, whoe was observed, without occasion, to be liberall in disposeing
#                     of mony to some of the officers of the store in a way more then was ordinary for his Lordship: The
#                     last Session of Parliament being proroged, & the time drawing nere for putting their designe in
#                     execution, There was a greate meeting appointed of the heads of the Romishe Clergie & other lay
#                     men of their faction, said to be att the Abbey of Multifarnam  in the
#                  xxiijth of November Counsell Parliament
#                         s
#                      Erle of
#                     Strafford
#                             ttee
#                          Lord Maguire in the   Where a Convent of ffranciscan friers, being openly and peaceably
#                     possessed of the monastery (, the daie of their meeteing being alsoe on their  ,) about
#                     the begining of  , but the time & place I cannott confidently affirme, yet
#                     wheresoeuer, their seuerall opinions, & discussions are as followe, like as I have receaved
#
#                     from a frier a franciscan & present there, being a guardian of that order, Therevpon a man, and
#                     many others there agitated, And the question was what course should be taken with the English, and
#                     all others that were fownd in the whole kingdome to be protestants  The Councell was therein
#                     devided Some were for their banishment, without attempting on their lives: For this was given
#                     the  s expellinge out of Granado & other parts of his Dominions the Mores, to the
#                     number of many hundreds of thowsands, All of them being dismissed with their lives, wives &
#                     children, with some part of their goods, if not the most parte,: That this his way of proseeding
#                     redownded much to the honor of Spaine: Whereas the slaughters of many Innocents would have laid an
#                     everlasting blemish of cruelty on that state, That the vsage of the English, their neighbours, &
#                     to whome many there present owed (if noe more) yet their education, would gaine much to the cawse
#                     both in   & other parts; That their goods & estats seazed vpon would be sufficient,
#                     without medleing with their persons; That if the contrary course were taken, and their blood spilt,
#                     besides the curse it would drawe from heaven vpon their cawse, it might withall incense &
#                     provoake the neighbour   to the takeing of a more severe Revenge on them and
#                     theires, even to extirpation (if it had the
#
#                     hand) On the other side was vrged a Con
#
#                     y proceeding to the vtter cutting off them and theires, & to instance of the dismissed Moores,
#                     Itt was answered That that was the sole Act of the king &   contrary to the
#                     advise of their Counsell, Which howsoever it might gaine that prince a name of mercie: yet therein
#                     the event shewed him to be most vnmercifull, not only to his owne but to all Chrissendome besides:
#                     That this was evident in the greate and excessive charge, that Spaine hath bin since that time putt
#                     vnto, by theis Moores, and their posterity to this day, All Chrissendome alsoe hath and doth still
#                     groane vnder th
#
#                     miseries it doth suffer, by the piracie of Algiers, Sally & the like Denne of theeves: That all
#                     this might
#                     77
#                  County of Westmeath St Francis day October last
#                         them
#                      Kinge of Spaine England Kingdome of England
#                             trar
#                          Queene of Spaine
#                             e
#
#                         266
#                      might haue bin prevented in one howre by a generall massacre, applying that it was noe lesse
#                     dangerous to expell the English, that theis robbed & banished men might againe returne with
#                     their swords in their hands, Whoe (by their hard vsage in spoileing, might be exasperated, & by
#                     the hope of recouering their former estates, would be animated farr more then strangers that would
#                     bee sent against them, being neither in their persons greeved, nor Iniured in their estats; That
#                     therefore a generall Massacre were the saffest, and readiest way, for
#
#                     freeing the Kingdome of any such feares: In which diuersity of opinion, howsoeuer the first
#                     prevailed with some, for which the ffranciscans (saith this guardian) did stand, yet others,
#                     inclineing to the second, Some againe leaneing to a middle way neither to dimisse nor kill; And
#                     according to this doe we finde the event, & course of their proseedings In some places they are
#                     generally putt to the sword, to other miserable ends: Some restraine their persons in durance,
#                     knowing it to bee in their handes to dispatch them att their pleasure, in the meane time they being
#                     preserved either for proffitt by their ransome, or by exchange for prisoners, or gaineing their owne
#                     pardons by the Lives of their prisoners if time would serve, or by their death (if the worst did
#                     happen) to satisfy their fury
#
#                     rayments, exposeing the miserable wretches
#                      Hitherto of their Councells & the effects of them: Nowe for their intentions, (All being
#                     reduced, (which god forbid) into their power) And thereof doe they, as by some lawe, give such
#                     peremptory conclusions, that it may well be wondered, the thoughts of men professing themselves wise
#                     should be soe vaine, And herein doe I still followe mine informer 1 first their lojalty to his
#                     Maiestie shalbe thus reserved, Thus (say they, of the modest sort;) But both his Revenues &
#                     gouermente must be reduced to some certeine bowndes; His rents none other then the ancient
#                     reservations before the plantacions, & the Customes soe ordered as to them shalbe thought
#                     fitting: 2 Secondly for the gouerment, such as would be esteemed lojall would have it committed
#                     to the handes of twoe lords Justices, one of the ancient Irish race the other of the ancient
#                     Brittish inhabitants of the Kingdome, provided that they be of the Romish profession, 3 Thirdly
#                     that a parliament be forthwith called consisting of whom they shall thinck fitt to be admitted,
#                     wherein their owne Religious men shalbe assistants 4 fowrthly Poineings act must be repealed
#                     &   declared to be a Kingdome independent of England, & without any referrence vnto it
#                     in any case whatsoever All
#
#                         The third sort at the first dismissed their prisoners but first haveing spoiled them of their
#                         goods &
#
#                         to cold & famine whereby many have perrished by deaths, worse then the sword or halter
#                      Ireland
#                             acts
#                          5 All acts preiudiciall to the Romish Religion shalbe abolished & it to be enacted, that
#                     there bee noe other profession in the Kingdome but the Romish 6 That only the ancient Nobility
#                     of the Kingdome shall stand, and of them such as shall refuse to conforme to the Romish Religion to
#                     be removed, and others putt in their Roome, Howsoever the present   must be putt out,
#                     and another putt in his place 7 All plantacion lands to be recalled, and the ancient proprieters
#                     to be reinvested in their former estates, With the limitations in their Covenant expressed, That
#                     they had not formerly sold their interests for valuable Consideracions 8 That the respective
#                       be subdevided, & certaine bownds or Barronies assigned to the cheefe
#                     septs and others of the nobility, Whoe are to be answearable for the gouernement thereof & that
#                     a standing Army may be still in being, The respective governors being to keepe a certeine number of
#                     men to be ready at all riseings out, (as the terme it) They alsoe being to builde & manteine
#                     certeine fortresses in places most convenient within their precincts: And that theis gouernors be of
#                     absolute power, only responsible to the parliament 9 Lastly for mainteineing a Correspondencie
#                     with other nations & for secureing the Coasts, that alsoe they may be rendered considerable vnto
#                     others, a navie of certeine number of shipps is to be manteined That to this end, five howses are to
#                     be accompted one in each province, accompting Meath for one of them, That to theis howses shalbe
#                     allotted an Anuall pention of certeine Thowsands of powndes, to be made vp of landes appropriate to
#                     Abbeys: And a further Contribution to be raised in the respective provinces to that end, That theis
#                     howses are to be assigned to a certeine order of Knights, answereable to that of Malta, Whoe are to
#                     be seamen; & to mainteine this fleete, That all prices are to bee apportioned, Some part for a
#                     Comon banck the rest to bee devided, ffor which purpose the felling of wood serviceable for this vse
#                     is to bee forbidden: The howse for this purpose
#
#                     to bee assigned to Leinster is Kilmainham, or rather Howth, Provided he Joine with them, That howse
#                     being esteemed most convenient in respect of scituation, For effecting of all which they cast vp
#                     the accompt of the forces of this kingdome, That it is able to make vpp readily Two  Erle of Kildare Countie of the Kingdome
#                         is
#
#                             hundred
#
#                             78
#
#                                 267
#                              hundred thowsand able men wanting onely Comanders, & some expert souldiers for the present
#                     with Armes and Amunition of all which they expect a speedy supply out of Flaunders Their owne
#                     Regiments there exercised being to be sent over & some shipping from Spaine allotted for that
#                     service, That this kingdome being settled, there are 30000 men to bee sent into England, to Joine
#                     with the french and spanish forces, and then Jointly to falle vpon Scotland, for reduceing both
#                     Kingdomes to the obedience of the pope, Which being finished, they have engaged themselves to the
#                       for assisting him against the Hollanders, & giveing their Rebellion (as they
#                     terme it) its due correction: And thus have I laid downe all that I heard related, omitting what I
#                     fynd others more Largely to insist vpon, All which their treacherous, vaine & ayrie projects God
#                     disapointe. As for my owne private sufferings by the present Rebellion: I referr them to another
#                     scedule, this being soe farr taken vpp Jur iijo Marcij 1641 coram Roger Puttock, Jo: Sterne,
#                     Johanne Watson, Willelmo Aldrich & Willelmo Hitchcock Kinge of Spaine
#                             John Sterne
#
#                             John Watson
#
#                             Roger Puttock
#
#                             William Aldrich
#
#                             William Hitchcock
#                          #xd;Dublin#xd;  I   Doctor in Divinity in obedience
#                     to his majesty's commission requiring an accompt of the losses of his loyal subjects wherein they
#                     suffered by the present Rebellion in Ireland, & requiring an accompt of what traitorous words,
#                     projects or Actions were done, said, or plotted by the actors, or by the Abettors in that rebellion
#                     Do make and give in this following report of the premises to the best of my knowledge upon oath viz,
#                     As for the present Rebellion Howsoever the first breaking out of this fire into a flame began first
#                     on the   yet was it smoking (as may well be conjectured, for many years before
#                     God having given us many and apparant grounds for the discovery of it, had they been duly considered
#                     on, or duly prosecuted to a discovery, Of which kind we find these former following
#                     particulars#xd;First that about  , amongst many books brought into the City of
#                     Limerick from forrain parts, & seized upon by the reverend Bishop of that Sea as prohibited
#                     (being thereunto authorized by the state) one had a written addition to the first part which was
#                     printed, containing a discourse of the friars of the Augustine order, sometimes seated in the town
#                     of Armagh in Ulster But by reason of the times,  at that present
#                     Resident (as that writing imported) in the City of Limerick in Mounster, That whylest it flourished
#                     at Armagh, it was protected, & largely provided for by the then Earl of Tirone Since whose
#                     expulsion out of Ireland, that Convent was also decayed & driven to those distresses it did for
#                     the present undergo, but that within   (This is as I remember, the time limitted) Ireland
#                     should find, he had a son inheriting his fathers virtues Who should restore that kingdom to its
#                     former liberty, & that Convent to its first lustre or words to that effect, This was related
#                     unto me by that zealous & learned prelate  , now Bishop of Limerick who saw & read
#                     the said passages Purposeing (as his Lordship told me) to send that book to the   to be taken into further consideration#xd;2 Hereunto was added a second passage about the
#                     same time at Limerick aforesaid, Where a popish priest gave out That within   there should not
#                     be a protestant in Ireland, or words to that purpose, with some other material Circumstances which I
#                     do not now remember, yet all so concurring with the former, (or the first with this) which precede I
#                     know not but being about one time) That it was thought fitting to be considered of, The said priest
#                     being sent to the Lords at Dublin & he committed to the Castle #xd;The#xd;  75
#                  Exw#xd;137 Henry Jones xxiiith of October 1641 3 or 4 years since and 3 years Doctor Webb Lord President of
#                     Mounster 3 years 264
#                      #xd;3 The third did agree with the two former, and fell out about the same time in the County of
#                     Meath in Leinster Where one Walter Nugent of Rathaspick in the said County eldest son to Walter
#                     Nugent Esquire (a man of great fortunes) upbraiding an Irish protestant, who was parish Clerk of
#                     Rathaspick aforesaid) with his Religion, & both speaking Latin, the said Nugent uttered these
#                     words. Infra tres annos venient tempus & potentia in Hibernia quando tu long (Likely meaning,
#                     diu) pendebis in cruce propter diabolicam vestram religionem The party to which this was spoken,
#                     fearing the power of the man durst not speak of it, only in private, yet being called upon &
#                     examined Juridically upon his oath, he deposed these words & being demanded whether the words
#                     were in Hiberniam or in Hibernia, The first importing an Invasion, the other an insurrection at
#                     home, he deposed the later, (having time given him to consider of it) These Examinations were sent
#                     to Sir  , Nugent was sent for & Committed to the Castle, & remained in long
#                     durance but afterwards dismissed &c#xd;4 Hereunto was added a fourth, about the same time near
#                     the Naas about 12 miles from Dublin, Where a papist priest (newly arrived out of flanders, did make
#                     his address to the then lord Deputy, & informed his lordship of an intercourse of letters
#                     between the Earl of Tirone with others in flanders, and the Popish Primate of Armagh, Reilly,
#                     concerning an invasion within a short time intended upon Ireland, The said priest offering, (so his
#                     person might be secured) to direct such as should be thereunto appointed to the place where the said
#                     Letters lay in the Custody of the said Reilly, Reilly was thereupon sent for, together with the
#                     popish Vicar general of Armagh (as I remember it Both were Committed to the Castle  , but soon after released, & the Informer dismissed with x
#                     li. and a suit of Clothes, or some such Reward #xd;Hereunto
#                  George Radcliff of Dublin #xd;Hereunto may be further added, (yet not so plain as the former) That about the same time the Lord
#                     Baron of Dunsany did ride disguised through   Munster, pretending to
#                     satisfy his curiosity in the knowledge of places & persons, He not being discovered until his
#                     return at the Birr, Where having offered himself to be bound for one in his Company, he wrote
#                     himself in his own stile, Being loath to leave under his hand a testimony of his disguised person
#                     and assumed name#xd;To descend now from the antecedents of this treason to the falling in thereupon,
#                     and lastly to the Consequents, & what thereby has been intended, (supposing it to succeed) &
#                     that it attained the desired effect, which by them was not doubted of And first for the entrance
#                     thereinto Howsoever that the ground work were long since laid, yet would they not have it so to
#                     seem, But new occasion must be found as the sole cause of their breaking out, This being intended
#                     for satisfying the minds of such of their own as have not hitherto been acquainted with the depth
#                     and misery of this iniquity, that they might   stand amazed at the
#                     suddenness of the undertaking, or stand of from Joining with them in the worst part of their
#                     designs, it being an apparant Rebellion, The fittest means for this must have been by casting
#                     aspersions on the present government, which (if longer tolerated) would prove extremely dangerous
#                     not only to their religion but their lives & posterity For effecting whereof reports were cast
#                     out, That in the Parliament of England, the cutting off of all the papists in Ireland, of what
#                     degree soever, was concluded upon, The execution of that Resolution being committed to the Council
#                     in Ireland The Lords (said they) had laid down a day for this work, being the xxiiith day of
#                     November then next following & now last past or thereabouts, for the better more secure, &
#                     more secret managing of this pretended plot Such of the popish nobility & gentry of both houses
#                     as appeared in Parliament at Dublin should be secured, & for the drawing together the rest
#                     (amongst other pretences) this alleged to be one, That his #xd;majesties#xd;  76
#                  all not 265
#                      #xd;majesties rents were purposely omytted, & not called upon in Easter term with that
#                     earnestness as formerly, and that such as made default should be summoned to appear at Michaelmas
#                     term at Dublin, and there surprised Such of them as were then in the Country (wanting their heads,
#                     being easily cut off) They say that this pretended plot was (I know not how) discovered to them So
#                     that for the safety of their lives & profession they were enforced to stand upon their guard,
#                     & to counterworke that day of the  , laid for their destruction by their
#                     declaring themselves in Arms on the  (a month before) The serious part of this
#                     discourse was related to me, by a friar intimate in their Counsel, & by a priest (a popish Vicar
#                     general), thereby to give me satisfaction, and to justify their proseedings Which names I do for the
#                     present forbear, in respect of his majesties service #xd;By others also I was informed, That this
#                     plot was mainly intended in that Session of Parliament next after the Earl of Straffords beheading,
#                     & the manner concluded upon in the popish private meetings, which were then observed to be
#                     frequent, & by some suspected might prove dangerous And that for discovery of what proportion of
#                     Arms & Ammunition our store of Dublin afforded (It being by some suspected that most was carried
#                     before to Carickfergus, One of the popish faction in the house  of
#                     Commons put one of the protestant members to move & enforme That some of the Earl of Straffords
#                     men had cast out some threatening words against the parliament in revenge of his Lord which could
#                     not be conceived to end in less then a blowing up of the whole houses of Parliament, the store lying
#                     under them, Whereupon a Commi
#
#                     of both houses (many of them prime papists) were appointed to make search in odd Corners, Amongst
#                     these, the   was one, who was observed, without occasion, to be liberal in disposing of
#                     money to some of the officers of the store in a way more then was ordinary for his Lordship#xd;The
#                     last Session of Parliament being proroged, & the time drawing near for putting their design in
#                     execution, There was a great meeting appointed of the heads of the Romish Clergy & other lay men
#                     of their faction, said to be at the Abbey of Multifarnam #xd;in the
#                  xxiiith of November  xxiiith of October s ttee Lord Maguire #xd;in the County of Westmeath Where a Convent of franciscan friars, being openly and peaceably
#                     possessed of the monastery (, the day of their meeting being also on their St Francis day,) about
#                     the beginning of October last, but the time & place I cannot confidently affirm, yet
#                     wheresoever, their several opinions, & discussions are as follow, like as I have received   from a friar a franciscan & present there, being a guardian of that order, Thereupon a
#                     man, and many others there agitated, And the question was what course should be taken with the
#                     English, and all others that were found in the whole kingdom to be protestants #xd;The Counsel was
#                     therein divided#xd;Some were for their banishment, without attempting on their lives For this was
#                     given the King of Spaines expelling out of Granado & other parts of his Dominions the More, to
#                     the number of many hundreds of thousands, All of them being dismissed with their lives, wives &
#                     children, with some part of their goods, if not the most part That this his way of proseeding
#                     redownded much to the honor of Spaine Whereas the slaughters of many Innocents would have laid an
#                     everlasting blemish of cruelty on that state, That the usage of the English, their neighbours, &
#                     to whom many there present owed (if no more) yet their education, would gain much to the cause both
#                     in England & other parts That their goods & estates seized upon would be sufficient, without
#                     medleing with their persons That if the contrary course were taken, and their blood spilt, besides
#                     the curse it would draw from heaven upon their cause, it might withal incense & provoke the
#                     neighbour Kingdom of England to the taking of a more severe Revenge on them and theirs, even to
#                     extirpation (if it had the
#
#                     hand)#xd;On the other side was urged a Con
#
#                     proceeding to the utter cutting of them and theirs, & to instance of the dismissed Moores, It
#                     was answered That that was the sole Act of the king & Queen of Spain contrary to the advise of
#                     their Counsel, Which howsoever it might gain that prince a name of mericke yet therein the event
#                     shown him to be most merciful, not only to his own but to all Chrissendome besides That this was
#                     evident in the great and excessive charge, that Spain has been since that time put to, by these
#                     Moors, and their posterity to this day, All Chrissendome also has and does still groan under th>
#                     miseries it does suffer, by the piracy of Algiers, Sally & the like Den of thieves That all
#                     this#xd;might#xd;  77
#                  them
#                      trar e 266 #xd;might have been prevented in one hour by a general massacre, applying that it was no less
#                     dangerous to expel the English, that these robbed & banished men might again return with their
#                     swords in their hands, Who (by their hard usage in spoiling, might be exasperated, & by the hope
#                     of recovering their former estates, would be animated far more then strangers that would be sent
#                     against them, being neither in their persons grieved, nor Injured in their estates; That therefore a
#                     general Massacre were the safest, and readiest way, for
#
#                     freeing the Kingdom of any such fears In which diversity of opinion, howsoever the first prevailed
#                     with some, for which the franciscans (says this guardian) did stand, yet others, inclineing to the
#                     second, Some again leaning to a middle way neither to dimisse nor kill And according to this do we
#                     find the event, & course of their proseedings In some places they are generally put to the
#                     sword, to other miserable ends Some restrain their persons in durance, knowing it to be in their
#                     hands to dispatch them at their pleasure, in the meantime they being preserved either for profit by
#                     their ransome, or by exchange for prisoners, or gaining their own pardons by the Lives of their
#                     prisoners if time would serve, or by their death (if the worst did happen) to satisfy their fury   rayments, exposing the miserable wretches  #xd;Hitherto of their Counsels
#                     & the effects of them Now for their intentions, (All being reduced, (which god forbid) into
#                     their power) And thereof do they, as by some law, give such peremptory conclusions, that it may well
#                     be wondered, the thoughts of men professing themselves wise should be so vain, And herein do I still
#                     follow mine informer#xd;1 first their lojalty to his Majesty shall be thus reserved, This (said
#                     they, of the modest sort) But both his Revenues & government must be reduced to some certain
#                     bounds His rents none other then the ancient reservations before the plantations, & the Customs
#                     so ordered as to them shall be thought fitting#xd;2 Secondly for the government, such as would be
#                     esteemed lojall would have it committed to the hands of two lords Justices, one of the ancient Irish
#                     race the other of the ancient British inhabitants of the Kingdom, provided that they be of the
#                     Romish profession,#xd;3 Thirdly that a parliament be forthwith called consisting of whom they shall
#                     think fit to be admitted, wherein their own Religious men shall be assistants#xd;4 fourthly
#                     Poineings act must be repealed & Ireland declared to be a Kingdom independent of England, &
#                     without any reference unto it in any case whatsoever#xd;All
#                      The third sort at the first dismissed their prisoners but first having
#                         spoiled them of their goods &
#                      to cold & famine whereby
#                         many have perished by deaths, worse then the sword or halter acts #xd;5 All acts preiudiciall to the Romish Religion shall be abolished & it to be enacted, that
#                     there be no other profession in the Kingdom but the Romish#xd;6 That only the ancient Nobility of
#                     the Kingdom shall stand, and of them such as shall refuse to conform to the Romish Religion to be
#                     removed, and others put in their Room, Howsoever the present Earl of Kildare must be put out, and
#                     another put in his place#xd;7 All plantation lands to be recalled, and the ancient proprieters to be
#                     reinvested in their former estates, With the limitations in their Covenant expressed, That they had
#                     not formerly sold their interests for valuable Considerations#xd;8 That the respective County of the
#                     Kingdom be subdevided, & certain bounds or Baronies assigned to the chief septs and others of
#                     the nobility, Who are to be answerable for the government thereof & that a standing Army may be
#                     still in being, The respective governors being to keep a certain number of men to be ready at all
#                     riseings out, (as the term it) They also being to build & manteine certain fortresses in places
#                     most convenient within their precincts And that these governors be of absolute power, only
#                     responsible to the parliament#xd;9 Lastly for maintaining a Correspondency with other nations &
#                     for securing the Coasts, that also they may be rendered considerable unto others, a navy of certain
#                     number of ships is to be manteined That to this end, five houses are to be accompted one in each
#                     province, accompting Meath for one of them, That to these houses shall be allotted an Anual pention
#                     of certain Thousands of pounds, to be made up of lands appropriate to Abbeys And a further
#                     Contribution to be raised in the respective provinces to that end, That these houses are to be
#                     assigned to a certain order of Knights, answerable to that of Malta, Who are to be seamen & to
#                     maintain this fleet, That all prices are to be apportioned, Some part for a Common bank the rest to
#                     be divided, for which purpose the felling of wood serviceable for this use is to be forbidden The
#                     house for this purpose   to be assigned to Leinster is Kilmainham,
#                     or rather Howth, Provided he Join with them, That house being esteemed most convenient in respect of
#                     situation,#xd;For effecting of all which they cast up the accompt of the forces of this kingdom,
#                     That it is able to make up readily Two #xd;
#
#                     #xd;
#                      is hundred
#                             78
#                          267 #xd;hundred thousand able men wanting only Commanders, & some expert soldiers for the present
#                     with Arms and Ammunition of all which they expect a speedy supply out of Flaunders Their own
#                     Regiments there exercised being to be sent over & some shipping from Spain allotted for that
#                     service, That this kingdom being settled, there are 30000 men to be sent into England, to Join with
#                     the french and spanish forces, and then Jointly to fall upon Scotland, for reducing both Kingdoms to
#                     the obedience of the pope, Which being finished, they have engaged themselves to the King of Spain
#                     for assisting him against the Hollanders, & giving their Rebellion (as they term it) is due
#                     correction And thus have I laid down all that I heard related, omitting what I find others more
#                     Largely to insist upon, All which their treacherous, vain & airy projects God disapointe. As for
#                     my own private sufferings by the present Rebellion I refer them to another scedule, this being so
#                     far taken up#xd;Jur iii   coram Roger Puttock, John Sterne, John Watson, William Aldrich
#                     & William Hitchcock#xd;
#                  March 1641 John Sterne John Watson Roger Puttock William Aldrich William Hitchcock

# %%
sentence = '''
Hereunto may be further added, (yet not so plain as the former) That about the same time the Lord
Baron of Dunsany did ride disguised through all Munster, pretending to
satisfy his curiosity in the knowledge of places and persons, He not being discovered until his
return at the Birr, Where having offered himself to be bound for one in his Company, he wrote
himself in his own stile, Being loath to leave under his hand a testimony of his disguised person
and assumed name.
'''

# %%
body_sp = sp_nlp_en(str(sentence))

# %%
body_sp.ents[0].

# %%
for token in body_sp.ents:
    print(token, token.label_, )
# Out:
# Hereunto PERSON
# Dunsany PERSON
# Munster GPE
# Birr LOC
# one CARDINAL
# Company ORG

# %%
bulletproof = lambda text: '( |<.*>|)+'.join(text.strip().replace(' ',''))
assert len(re.findall(bulletproof('12th of'),r'12th <del rend="doublestrikethrough">of')) == 1
assert len(re.findall(bulletproof('12th of'),r'12th<del rend="doublestrikethrough">of')) == 1

# %%
body_sp.ents[2].text
# Out:
# 'John Watson Dublin'

# %%
entities
# Out:
# [William Aldrich William Hitchcock Roger,
#  John Sterne,
#  John Watson Dublin,
#  Diuinity,
#  Abettors,
#  Howsoever,
#  first,
#  First,
#  Sea,
#  first,
#  Augustine,
#  Ireland,
#  Convent,
#  &,
#  Ireland,
#  Whoe,
#  Convent,
#  first,
#  &,
#  Purposeing,
#  2,
#  Hereunto,
#  second,
#  Limrick,
#  first,
#  about one,
#  Lords,
#  Castle,
#  75,
#  Exw,
#  137,
#  Ireland,
#  October 1641,
#  3,
#  4,
#  Armagh,
#  Vlster,
#  Limrick,
#  Webb,
#  Mounster,
#  3 yeres,
#  Ireland,
#  Dublin,
#  264,
#  third,
#  one,
#  Walter Nugent,
#  Rathaspick,
#  County,
#  Walter,
#  Nugent Esquire,
#  Irish,
#  Clearke,
#  Rathaspick,
#  Religion, & both,
#  Latine,
#  Nugent,
#  first,
#  Invasion,
#  Theis Examinacions,
#  Nugent,
#  & Committed,
#  Castle, &,
#  &,
#  4,
#  Hereunto,
#  Naas,
#  about 12 miles,
#  &,
#  the Popish Primate of Armaghe,
#  Custodie,
#  Relye,
#  Armaghe,
#  & the Informer,
#  Meath,
#  Leinster,
#  Hiberniam Hibernia,
#  Dublin Erle,
#  Tirone Ireland Castle
#
#                          ,
#  Dublin,
#  Munster,
#  Birr,
#  the Consequents, &,
#  first,
#  Howsoeuer,
#  Joineing,
#  Ireland,
#  Lords,
#  a day,
#  day of November,
#  &,
#  76,
#  Dunsany,
#  Parliament of England,
#  Ireland,
#  Parliament,
#  Dublin,
#  265,
#  Dublin,
#  Cuntrie,
#  Armes,
#  October,
#  Erle,
#  Straffords,
#  Armes & Amunition,
#  Dublin,
#  Carickfergus,
#  One,
#  Commons,
#  &,
#  Paliament,
#  Wherevpon,
#  Corners,
#  the Romishe Clergie &,
#  the Abbey of Multifarnam,
#  November,
#  Counsell Parliament,
#  Strafford,
#  Maguire,
#  franciscan &,
#  English,
#  Councell,
#  Granado &,
#  Dominions the Mores,
#  of many hundreds,
#  English,
#  & estats,
#  Revenge,
#  &,
#  Moores,
#  Act,
#  &   ,
#  Counsell,
#  Chrissendome,
#  Moores,
#  this day,
#  Chrissendome,
#  Algiers,
#  Sally &,
#  Denne,
#  77,
#  Westmeath St Francis,
#  day October,
#  Spaine,
#  England Kingdome,
#  England,
#  Queene,
#  266,
#  English,
#  Whoe,
#  Massacre,
#  second,
#  Councells &,
#  Nowe,
#  1,
#  Maiestie,
#  Revenues &
#                      ,
#  & the Customes,
#  2,
#  one,
#  Irish,
#  Brittish,
#  Kingdome,
#  3,
#  Thirdly,
#  4,
#  Poineings,
#  &   ,
#  Kingdome,
#  England,
#  third,
#  first,
#  first,
#  Kingdome,
#  the Romish 6,
#  Nobility,
#  Kingdome,
#  the Romish Religion,
#  Roome,
#  Howsoever,
#  Covenant,
#  Consideracions,
#  Barronies,
#  Whoe,
#  Army,
#  9,
#  &,
#  Coasts,
#  five,
#  Meath,
#  one,
#  Anuall,
#  Thowsands of,
#  Knights,
#  Malta,
#  Whoe,
#  &,
#  Leinster,
#  Kilmainham,
#  Howth,
#  Joine,
#  Two,
#  Kildare Countie,
#  Kingdome,
#  hundred,
#  hundred,
#  Comanders, & some,
#  Armes,
#  Amunition,
#  Flaunders,
#  Spaine,
#  30000,
#  England,
#  Joine,
#  Scotland,
#  Kingdomes,
#  Hollanders, & giveing,
#  Jur,
#  Marcij 1641,
#  Roger Puttock,
#  Johanne Watson,
#  Willelmo Aldrich & Willelmo,
#  Hitchcock Kinge,
#  Spaine,
#  John Sterne,
#  John Watson
#
#                              ,
#  Roger Puttock
#
#                              ,
#  William Aldrich
#
#                              ,
#  William Hitchcock,
#  xd;Dublin#xd,
#  Rebellion,
#  Ireland,
#  &,
#  Actions,
#  Abettors,
#  Rebellion Howsoever,
#  first,
#  many years,
#  the City of
#                      Limerick,
#  &,
#  Bishop,
#  Sea,
#  first,
#  Augustine,
#  Armagh,
#  Ulster,
#  the City of Limerick,
#  Mounster,
#  Armagh,
#  Earl of Tirone,
#  Ireland,
#  Convent,
#  &,
#  Ireland,
#  Convent,
#  first,
#  &,
#  Bishop,
#  Limerick,
#  Purposeing,
#  Lordship,
#  Hereunto,
#  second,
#  Limerick,
#  Ireland,
#  first,
#  one,
#  the Lords at Dublin &,
#  Castle #xd;The#xd,
#  75,
#  October 1641 3 or 4 years,
#  3 years,
#  Webb,
#  Mounster,
#  264,
#  third,
#  two,
#  Meath,
#  Leinster,
#  one,
#  Walter Nugent,
#  Rathaspick,
#  County,
#  Walter,
#  Nugent Esquire,
#  Irish,
#  Rathaspick,
#  Religion, &,
#  Latin,
#  Nugent,
#  Hibernia quando,
#  Hiberniam,
#  Hibernia,
#  first,
#  Invasion,
#  Examinations,
#  Nugent,
#  & Committed,
#  Castle, &,
#  Hereunto,
#  fourth,
#  Naas,
#  about 12 miles,
#  Dublin,
#  &,
#  the Earl of Tirone,
#  the Popish Primate of Armagh,
#  Reilly,
#  Ireland,
#  Reilly,
#  Reilly,
#  Armagh,
#  & the Informer,
#  Clothes,
#  George Radcliff,
#  Dublin,
#  Dunsany,
#  Company,
#  the Consequents, &,
#  first,
#  thereinto Howsoever,
#  the Parliament of England,
#  Ireland,
#  the Council
#                      ,
#  November,
#  &,
#  Parliament,
#  Dublin,
#  xd;majesties#xd,
#  76,
#  265,
#  Easter,
#  Michaelmas,
#  Dublin,
#  that day,
#  Counsel, &,
#  &,
#  Arms & Ammunition,
#  Dublin,
#  Carickfergus,
#  One,
#  Commons,
#  one,
#  &,
#  Parliament,
#  Corners,
#  Lordship#xd;The,
#  the Romish Clergy &,
#  the Abbey of Multifarnam,
#  November,
#  October,
#  the County of Westmeath,
#  franciscan,
#  the beginning of October last,
#  franciscan &,
#  English,
#  Granado &,
#  Dominions the More,
#  many hundreds of thousands,
#  Spaine,
#  Innocents,
#  English,
#  England &,
#  &,
#  Kingdom of England,
#  Revenge,
#  &,
#  Moores,
#  Act,
#  & Queen,
#  Spain,
#  Chrissendome,
#  Spain,
#  this day,
#  Chrissendome,
#  Algiers,
#  Sally &,
#  Den,
#  77,
#  266,
#  one hour,
#  English,
#  Massacre,
#  the Kingdom of,
#  second,
#  the Lives of their,
#  Majesty,
#  Revenues &,
#  Secondly,
#  two,
#  one,
#  Irish,
#  British,
#  Kingdom,
#  Thirdly,
#  Poineings,
#  & Ireland,
#  Kingdom,
#  England,
#  third,
#  first,
#  first,
#  xd;5,
#  the Romish Religion,
#  the Kingdom but,
#  Kingdom,
#  the Romish Religion,
#  Howsoever,
#  Earl of Kildare,
#  Covenant,
#  Considerations#xd;8,
#  the
#                      Kingdom,
#  Baronies,
#  Army,
#  Correspondency,
#  Coasts,
#  five,
#  Meath,
#  one,
#  Anual,
#  Thousands of pounds,
#  Abbeys And,
#  Knights,
#  Malta,
#  &,
#  Leinster,
#  Kilmainham,
#  Howth,
#  Two,
#  hundred,
#  78,
#  267,
#  #xd;hundred thousand,
#  Flaunders,
#  Spain,
#  30000,
#  England,
#  Join,
#  Scotland,
#  Kingdoms,
#  the King of Spain,
#  Hollanders, &,
#  Rebellion,
#  Roger Puttock,
#  John Sterne,
#  John Watson,
#  William Aldrich,
#  March 1641,
#  John Sterne,
#  Watson Roger,
#  William Aldrich William Hitchcock]

# %%
entities = list([e for e in body_sp.ents]) 

for text_node in text_nodes:
    for fragment in text_node:
        for entity in entities:
            if entity.text in fragment:
                print(fragment)
                print(entity.text)
                print(entity.label_)
                print('...........................................')
                wrap_text_in_tag(fragment, entity.text, entity.label_)
                entities.pop(0)
# Out:
# , &
#                     requireing an accompt of what traiterous words, proiects or Actions were done, said, or plotted by
#                     the actors, or by the Abettors in that rebellion: Doe make and give in this following report of the
#                     premises to the best of my knowledge vpon oath: vizt, As for the present
# one
# CARDINAL
# ...........................................
#  from forraine parts, & seazed
#                     vpon by the reuerend Bishop of that Sea as prohibited (being therevnto authorized by the state) one
#                     had a written addition to the first part which was printed, conteyneing a discourse of the friers of
#                     the Augustine order, somtimes seated in the
# one
# CARDINAL
# ...........................................
# , or words to that purpose, with some other
#                     materiall Circumstances which I doe not now remember, yet all soe concurring with the former, (or
#                     the first with this) which precede I know not but being about one tyme) That it was thought fitting
#                     to be considered of, The said preist being sent to the Lords at
# one
# CARDINAL
# ...........................................
# Henry Jones
# one
# CARDINAL
# ...........................................
# Erle of
#                     Tirone
# one
# CARDINAL
# ...........................................
#
#                     Munster, pretending to satisfy his curiosity in the knowledg of places & persons, Hee not being
#                     discouered vntill his returne att the Birr, Where having offered himself to be bound for one in his
#                     Company, he writt himself in his owne stile, Being loath to leave vnder his hand a testemony of his
#                     disguised person and assumed name
# Company
# ORG
# ...........................................

# %%
fragment = re.search(bulletproof(ent.text), text)[0]
    print(fragment)
    parts = text.partition(fragment)
    tagged += parts[0] + f'<{ent.label_} class="proposed" model="spacy_en_core_web_md" count="{i}">{parts[1]}</{ent.label_}>'
    text = parts[2]
tagged += text
# Out:
#   File "<ipython-input-20-54cd4eb76842>", line 2
#     print(fragment)
#     ^
# IndentationError: unexpected indent

# %%
def wrap_text_in_tag(text,substring,tag_name):
    text_node = text.getparent()
    partitions = text.partition(substring)
    text_node.tail = partitions[0]
    
    newElement = et.Element(tag_name)
    newElement.text = partitions[1]
    newElement.tail = partitions[2]
    
    index = text_node.getparent().index(text_node) + 1
    text_node.getparent().insert(index,newElement)

# %%
body_sp.ents[i].text in text_nodes[1][0]
# Out:
# True

# %%
et.fromstring(tagged)
# Out:
# Traceback (most recent call last):
#
#   File "/home/alex/projects/collaborative-platform_venv/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 3326, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   File "<ipython-input-70-fa860d7c781a>", line 1, in <module>
#     et.fromstring(tagged)
#
#   File "src/lxml/etree.pyx", line 3234, in lxml.etree.fromstring
#
#   File "src/lxml/parser.pxi", line 1876, in lxml.etree._parseMemoryDocument
#
#   File "src/lxml/parser.pxi", line 1757, in lxml.etree._parseDoc
#
#   File "src/lxml/parser.pxi", line 1068, in lxml.etree._BaseParser._parseUnicodeDoc
#
#   File "src/lxml/parser.pxi", line 601, in lxml.etree._ParserContext._handleParseResultDoc
#
#   File "src/lxml/parser.pxi", line 711, in lxml.etree._handleParseResult
#
#   File "src/lxml/parser.pxi", line 640, in lxml.etree._raiseParseError
#
#   File "<string>", line 11
# XMLSyntaxError: Unescaped '<' not allowed in attributes values, line 11, column 36

# %%
body.getparent().replace(body, et.fromstring(tagged))

# %%
body_sp.ents[0].text
# Out:
# 'Trinity College Dublin Dublin'

# %%
body_text_filtered
# Out:
# 'Transcribed Version of Deposition\n                 Edited Edited Trinity College Dublin Dublin, Ireland Ireland Edward Lake Dublin Dublin Ireland Alderman Thomas Hicks Doctor Moore Ja: Ware 261 to 268 The examination of  Edward Lake  of Dublin Alderman taken the 12th of November  1641 : upon oath  before ministred by  the clerk of the Councell by direction of the board A\n                      The said examinate saith that about July Last he being then in London\n                     and supping at and usually resorting to  the house of  Thomas Hicks  an apothecary in\n                    Fleetestreete where one  Doctor Moore  usually  lodged the examinate\n                    & his wife one night being at Supper with the said  Thomas Hicks . the said  Doctor Moore  being\n                    then likewise at Supper with them asked him why he did not Live in England seing that he had given\n                    over  B  his trading. To which the examinate answered that he chose\n                    rather to Live in Ireland because the Little means he had was there. whereupon the said  Doctor Moore \n                    replyed that it was much to be feared that there would be ould cutting of throats in Ireland er it\n                    were Long. Edw: Lake Coram me Ja: Ware\n                 12  No 1641 Examjnation of Edward Lake concerning a\n                    conference  betweene him &  Doctor Moore  in  London. James Ware #xd;261 to 268#xd;The examination of  Edward Lake  of Dublin Alderman taken the 12th of November  1641 Upon oath\n                     before ministered by \n                    the clerk of the Council by direction of the board#xd; A  The said\n                    examinant says that about July Last he being then in London\n                     and supping at and usually resorting to \n                    the house of  Thomas Hicks  an apothecary in Fleetestreete where one  Doctor Moore  usually\n                      lodged the examinant & his wife one night being at Supper with the said  Thomas Hicks . the\n                    said  Doctor Moore  being then likewise at Supper with them asked him why he did not Live in England\n                    seeing that he had given over  B  his trading. To which the examinant\n                    answered that he chose rather to Live in Ireland because the Little means he had was there.\n                    whereupon the said  Doctor Moore  replied that it was much to be feared that there would be old\n                    cutting of throats in Ireland er it were Long.#xd; Edward Lake #xd;Coram me#xd;James Ware\n                 #xd;#xd;12\n                     No 1641 #xd;Examination of Edward#xd;Lake concerning a conference\n                    #xd;between him &  Doctor Moore  in #xd;London.#xd;#xd;\n                 James Ware'

# %%
print(et.tostring(body).decode('UTF-8'))
# Out:
# <body xmlns="http://www.tei-c.org/ns/1.0" xmlns:xi="http://www.w3.org/2001/XInclude">
#       <div type="deposition">
#         <closer>
#           <signed>
#             <roleName type="Commissioner"/>
#             <name>Ja: Ware</name>
#           </signed>
#         </closer>
#       </div>
#       <div type="original">
#         <pb n="fol. 164r" pagenum="261"/>
#         <p><lb/>261 to 268<lb/>The examination of <person sameAs="person809164r087-1">Edward Lake</person> of Dublin Alderman taken the 12th of November <del rend="doublestrikethrough">1641</del>: upon oath <del rend="strikethrough">before</del>
#                     <add place="inline">ministred by</add> the clerk of the Councell by direction of the board<lb/><note type="marginalia">A
#                     </note> The said examinate saith that about July Last he being then in London
#                     <del rend="strikethrough"><add place="inline">and supping</add></del>
#                     <del rend="strikethrough">at</del>
#                     <add place="inline">and usually resorting to</add> the house of <person sameAs="person809164r087-2">Thomas Hicks</person> an apothecary in
#                     Fleetestreete where one <person sameAs="person809164r087-3">Doctor Moore </person><del rend="strikethrough">usually</del> lodged the examinate
#                     &amp; his wife one night being at Supper with the said <person sameAs="person809164r087-2">Thomas Hicks</person>. the said <person sameAs="person809164r087-3">Doctor Moore</person> being
#                     then likewise at Supper with them asked him why he did not Live in England seing that he had given
#                     over <note type="marginalia">B</note> his trading. To which the examinate answered that he chose
#                     rather to Live in Ireland because the Little means he had was there. whereupon the said <person sameAs="person809164r087-3">Doctor Moore</person>
#                     replyed that it was much to be feared that there would be ould cutting of throats in Ireland er it
#                     were Long.<lb/>Edw: Lake<lb/>Coram me<lb/>Ja: Ware
#                 </p>
#         <pb n="fol. 164v"/>
#         <p/>
#         <pb n="fol. 165r"/>
#         <p/>
#         <pb n="fol. 165v" pagenum="12"/>
#         <p><lb/><lb/>12 <del rend="doublestrikethrough">No</del>
#                     <del rend="doublestrikethrough">1641</del><lb/>Examjnation of Edward<lb/>Lake concerning a
#                     conference <lb/>betweene him &amp; <person sameAs="person809164r087-3">Doctor Moore</person> in <lb/>London.<lb/><lb/>
#                 </p>
#         <closer>
#           <signed>
#             <roleName type="Commissioner"/>
#             <name>James Ware</name>
#           </signed>
#         </closer>
#       </div>
#       <div type="normalised">
#         <pb n="fol. 164r" pagenum="261"/>
#         <p>#xd;261 to 268#xd;The examination of <person sameAs="person809164r087-1">Edward Lake</person> of Dublin Alderman taken the 12th of November <del rend="doublestrikethrough">1641</del>Upon oath
#                     <del rend="strikethrough">before</del>
#                     <add place="inline">ministered by</add>
#                     the clerk of the Council by direction of the board#xd;<note type="marginalia">A</note> The said
#                     examinant says that about July Last he being then in London
#                     <del rend="strikethrough"><add place="inline">and supping</add></del>
#                     <del rend="strikethrough">at</del>
#                     <add place="inline">and usually resorting to</add>
#                     the house of <person sameAs="person809164r087-2">Thomas Hicks</person> an apothecary in Fleetestreete where one <person sameAs="person809164r087-3">Doctor Moore </person><del rend="strikethrough">usually
#                     </del> lodged the examinant &amp; his wife one night being at Supper with the said <person sameAs="person809164r087-2">Thomas Hicks</person>. the
#                     said <person sameAs="person809164r087-3">Doctor Moore</person> being then likewise at Supper with them asked him why he did not Live in England
#                     seeing that he had given over <note type="marginalia">B</note> his trading. To which the examinant
#                     answered that he chose rather to Live in Ireland because the Little means he had was there.
#                     whereupon the said <person sameAs="person809164r087-3">Doctor Moore</person> replied that it was much to be feared that there would be old
#                     cutting of throats in Ireland er it were Long.#xd;<person sameAs="person809164r087-1">Edward Lake</person>#xd;Coram me#xd;James Ware
#                 </p>
#         <pb n="fol. 164v"/>
#         <p/>
#         <pb n="fol. 165r"/>
#         <p/>
#         <pb n="fol. 165v" pagenum="12"/>
#         <p>#xd;#xd;12
#                     <del rend="doublestrikethrough">No</del>
#                     <del rend="doublestrikethrough">1641</del>#xd;Examination of Edward#xd;Lake concerning a conference
#                     #xd;between him &amp; <person sameAs="person809164r087-3">Doctor Moore</person> in #xd;London.#xd;#xd;
#                 </p>
#         <closer>
#           <signed>
#             <rolename type="commissioner"/>
#             <name>James Ware</name>
#           </signed>
#         </closer>
#       </div>
#     </body>

# %%
node = text_nodes[1]

# %%
print(et.tostring(body).decode('UTF-8'))
# Out:
# <body xmlns="http://www.tei-c.org/ns/1.0" xmlns:xi="http://www.w3.org/2001/XInclude">
#       <div type="deposition">
#         <closer>
#           <signed>
#             <roleName type="Commissioner"/>
#             <name>Ja: Ware</name>
#           </signed>
#         </closer>
#       </div>
#       <div type="original">
#         <pb n="fol. 164r" pagenum="261"/>
#         <p><lb/><CARDINAL>261</CARDINAL> to 268<lb/>The examination of <person sameAs="person809164r087-1">Edward Lake</person><LOC>Edward Lake</LOC><GPE>Dublin</GPE> Alderman taken the 12th of November <CARDINAL>12</CARDINAL>th of November <GPE>Dublin</GPE> Alderman taken the 12th of November <del rend="doublestrikethrough">1641</del><CARDINAL>1641</CARDINAL><del rend="strikethrough">before</del>
#                     <add place="inline">ministred by</add> the clerk of the <PERSON>Councell</PERSON> by direction of the board<lb/><note type="marginalia">A
#                     </note> The said examinate saith that <DATE>about July Last</DATE> he being then in London
#                     <GPE>London</GPE>
#                     <GPE>London</GPE>
#                     <del rend="strikethrough"><add place="inline">and supping</add></del>
#                     <del rend="strikethrough">at</del>
#                     <add place="inline">and usually resorting to</add> the house of <person sameAs="person809164r087-2">Thomas Hicks</person><PERSON>Thomas Hicks</PERSON><PERSON>Fleetestreete</PERSON> where one <person sameAs="person809164r087-3">Doctor Moore </person>Doctor <PERSON>Moore</PERSON> <del rend="strikethrough">usually</del> lodged the examinate
#                     &amp; his wife one night being at <TIME>Supper</TIME> with the said <TIME>one night</TIME> being at Supper with the said <TIME>Supper</TIME> with the said <person sameAs="person809164r087-2">Thomas Hicks</person><PERSON>Thomas Hicks</PERSON><person sameAs="person809164r087-3">Doctor Moore</person>Doctor <PERSON>Moore</PERSON><WORK_OF_ART>Live in England</WORK_OF_ART> seing that he had given
#                     over <TIME>Supper</TIME> with them asked him why he did not Live in England seing that he had given
#                     over <note type="marginalia">B</note> his trading. To which the examinate answered that he chose
#                     rather to Live in <GPE>Ireland</GPE> because the Little means he had was there. whereupon the said <FAC>Live</FAC> in Ireland because the Little means he had was there. whereupon the said <person sameAs="person809164r087-3">Doctor Moore</person>Doctor <PERSON>Moore</PERSON><GPE>Ireland</GPE> er it
#                     were Long.<lb/>Edw: Lake<lb/>Coram me<lb/>Ja: Ware
#                 </p>
#         <pb n="fol. 164v"/>
#         <p/>
#         <pb n="fol. 165r"/>
#         <p/>
#         <pb n="fol. 165v" pagenum="12"/>
#         <p><lb/><lb/>12 <del rend="doublestrikethrough">No</del>
#                     <del rend="doublestrikethrough">1641</del><CARDINAL>1641</CARDINAL><lb/>Examjnation of Edward<lb/>Lake concerning a
#                     conference <lb/>betweene him &amp; <person sameAs="person809164r087-3">Doctor Moore</person>Doctor <PERSON>Moore</PERSON><lb/><GPE>London</GPE>.<lb/><lb/>
#                 </p>
#         <closer>
#           <signed>
#             <roleName type="Commissioner"/>
#             <name>James Ware</name>
#           </signed>
#         </closer>
#       </div>
#       <div type="normalised">
#         <pb n="fol. 164r" pagenum="261"/>
#         <p>#xd;261 to 268#xd;The examination of <person sameAs="person809164r087-1">Edward Lake</person> of Dublin Alderman taken the 12th of November <del rend="doublestrikethrough">1641</del><CARDINAL>1641</CARDINAL><del rend="strikethrough">before</del>
#                     <add place="inline">ministered by</add>
#                     the clerk of the <ORG>Council</ORG> by direction of the board#xd;<note type="marginalia">A</note> The said
#                     examinant says that <DATE>about July Last</DATE> he being then in London
#                     <del rend="strikethrough"><add place="inline">and supping</add></del>
#                     <del rend="strikethrough">at</del>
#                     <add place="inline">and usually resorting to</add>
#                     the house of <person sameAs="person809164r087-2">Thomas Hicks</person><PERSON>Thomas Hicks</PERSON><PERSON>Fleetestreete</PERSON> where one <person sameAs="person809164r087-3">Doctor Moore </person>Doctor <PERSON>Moore</PERSON> <del rend="strikethrough">usually
#                     </del> lodged the examinant &amp; his wife one night being at <TIME>Supper</TIME> with the said <TIME>one night</TIME> being at Supper with the said <person sameAs="person809164r087-2">Thomas Hicks</person>. the
#                     said <person sameAs="person809164r087-3">Doctor Moore</person>Doctor <PERSON>Moore</PERSON><WORK_OF_ART>Live in England</WORK_OF_ART>
#                     seeing that he had given over <TIME>Supper</TIME> with them asked him why he did not Live in England
#                     seeing that he had given over <note type="marginalia">B</note> his trading. To which the examinant
#                     answered that he chose rather to Live in <GPE>Ireland</GPE> because the Little means he had was there.
#                     whereupon the said <FAC>Live</FAC> in Ireland because the Little means he had was there.
#                     whereupon the said <person sameAs="person809164r087-3">Doctor Moore</person> replied that it was much to be feared that there would be old
#                     cutting of throats in Ireland er it were <GPE>Long.#xd</GPE>;<GPE>Ireland</GPE> er it were Long.#xd;<person sameAs="person809164r087-1">Edward Lake</person>#xd;Coram me#xd;James Ware
#                 </p>
#         <pb n="fol. 164v"/>
#         <p/>
#         <pb n="fol. 165r"/>
#         <p/>
#         <pb n="fol. 165v" pagenum="12"/>
#         <p>#xd;#xd;12
#                     <del rend="doublestrikethrough">No</del>
#                     <del rend="doublestrikethrough">1641</del><CARDINAL>1641</CARDINAL><MONEY>xd;between</MONEY> him &amp; <person sameAs="person809164r087-3">Doctor Moore</person> in #<MONEY>xd;London.#xd;#xd</MONEY>;
#                 </p>#<MONEY>xd;#xd;12</MONEY>
#                     <closer>
#           <signed>
#             <rolename type="commissioner"/>
#             <name>James Ware</name>
#           </signed>
#         </closer>
#       </div>
#     </body>

# %%
node[1][2]
# Out:
# ' of Dublin Alderman taken the 12th of November '

# %%
wrap_text_in_tag(node[1][2],'Dublin','place')

# %%
def wrap_text_in_tag(text,substring,tag_name):
    text_node = text.getparent()
    partitions = text.partition(substring)
    text_node.tail = partitions[0]
    
    newElement = et.Element(tag_name)
    newElement.text = partitions[1]
    newElement.tail = partitions[2]
    
    index = text_node.getparent().index(text_node) + 1
    text_node.getparent().insert(index,newElement)

# %%
text = node[1][0]
text_node = node[1][0].getparent()
partitions = text.partition('1 ato 2')
print(partitions)
text_node.tail = partitions[0]
# Out:
# ('26', '1 to 2', '68')

# %%
newElement = et.Element('a')
newElement.text = partitions[1]
newElement.tail = partitions[2]

# %%
# Out:
# 0

# %%
index = text_node.getparent().index(text_node) + 1
text_node.getparent().insert(index,newElement)
node[1][1]
# Out:
# 'The examination of '

# %%
newElement.tail = 'ewfdsx'

# %%
et.tostring(f_et)
# Out:
# b'<TEI xmlns:xi="http://www.w3.org/2001/XInclude" xmlns="http://www.tei-c.org/ns/1.0">\n  <!--<TEI>-->\n  <teiHeader>\n    <fileDesc>\n      <titleStmt>\n        <title>\n\n                </title>\n      </titleStmt>\n      <editionStmt>\n        <edition>Transcribed Version of Deposition\n                </edition>\n        <respStmt>\n          <resp xmlns="">Edited</resp>\n          <include xmlns="" href="responsiblePeople.xml" xpointer="RP2"/>\n        </respStmt>\n        <respStmt>\n          <resp xmlns="">Edited</resp>\n          <include xmlns="" href="responsiblePeople.xml" xpointer="RP4"/>\n        </respStmt>\n      </editionStmt>\n      <publicationStmt>\n        <publisher>Trinity College Dublin</publisher>\n        <pubPlace>Dublin, Ireland</pubPlace>\n      </publicationStmt>\n      <sourceDesc>\n        <include href="manuscriptDescription_tei.xml" xpointer="ms809"/>\n      </sourceDesc>\n    </fileDesc>\n    <encodingDesc>\n      <charDecl>\n            </charDecl>\n      <xi:include href="projectDesc.xml" xpointer="id1641-projectDesc"/>\n      <xi:include href="editorialDecl.xml" xpointer="id1641-editorialDecl"/>\n    </encodingDesc>\n    <profileDesc>\n      <creation>\n        <date when="1641_11_12"/>\n        <placeName>\n          <country>Ireland</country>\n        </placeName>\n      </creation>\n      <!-- Points to keywords in keywords.xml file -->\n      <textClass>\n        <keywords scheme="1641">\n          <list type="deposition_type">\n            <xi:include href="keywords.xml" xpointer="nod66"/>\n          </list>\n        </keywords>\n        <keywords scheme="1641">\n          <list type="nature_of_deposition">\n            <xi:include href="keywords.xml" xpointer="nod17"/>\n            <xi:include href="keywords.xml" xpointer="nod43"/>\n          </list>\n        </keywords>\n      </textClass>\n      <langUsage>\n        <language ident="en" usage="100"/>\n      </langUsage>\n      <particDesc>\n        <listPerson>\n          <person xml:id="person809164r087-1" sex="1">\n            <persName>\n              <roleName type="Deponent"/>\n              <forename>Edward</forename>\n              <surname>Lake</surname>\n            </persName>\n            <residence>\n              <placeName type="City">Dublin</placeName>\n              <region type="County">Dublin</region>\n              <country key="IRL">Ireland</country>\n            </residence>\n            <occupation>Alderman</occupation>\n          </person>\n          <person xml:id="person809164r087-2" sex="1">\n            <persName>\n              <roleName type="Mentioned"/>\n              <forename>Thomas</forename>\n              <surname>Hicks</surname>\n            </persName>\n          </person>\n          <person xml:id="person809164r087-3" sex="3">\n            <persName>\n              <roleName type="Mentioned"/>\n              <forename>Doctor</forename>\n              <surname>Moore</surname>\n            </persName>\n          </person>\n        </listPerson>\n      </particDesc>\n      <particDesc>\n        <listPlace/>\n      </particDesc>\n    </profileDesc>\n    <revisionDesc>\n      <change when="2009-01-08T10:09:13" who="responsiblePeople.xml#RP4"/>\n    </revisionDesc>\n  </teiHeader>\n  <!-- @corresp on <text> indicates that this transcription corresponds with the msItem identified in the msDesc file with this id. -->\n  <text corresp="outputFiles/manuscriptDescription_tei.xml#p809164r087">\n    <body>\n      <div type="deposition">\n        <closer>\n          <signed>\n            <roleName type="Commissioner"/>\n            <name>Ja: Ware</name>\n          </signed>\n        </closer>\n      </div>\n      <div type="original">\n        <pb n="fol. 164r" pagenum="261"/>\n        <p><lb/><CARDINAL>261</CARDINAL> to 268<lb/>The examination of <person sameAs="person809164r087-1">Edward Lake</person><LOC>Edward Lake</LOC><GPE>Dublin</GPE> Alderman taken the 12th of November <CARDINAL>12</CARDINAL>th of  ...

# %%
from typing import Iterable

from django.contrib.auth.decorators import login_required
from django.http import HttpRequest, HttpResponse
from django.shortcuts import render

from apps.views_decorators import objects_exists, user_has_access
from apps.files_management.models import File, FileVersion
from apps.projects.models import Project

from django.db.models import Q

import pandas as pd
from lxml import etree as et
from tqdm import tqdm

# %%
NAMESPACES = {'tei': 'http://www.tei-c.org/ns/1.0', 'xml': 'http://www.w3.org/XML/1998/namespace'}

# %%
project = Project.objects.get(title__exact='features')
files_query = Q(project=project)
files = File.objects.filter(files_query)

# %%
file = files[0] 
file.name
# Out:
# 'dep_839099r067_tei_(original_normalized_depositions_marked_persons_gazetteer_gazetteer_date_annotation).xml'

# %%
content = get_latest_content(file)

# %%
def create_summary_for_document(doc_raw: str, doc_name:str='undefined')->pd.DataFrame: 
    doc_tree = et.fromstring(doc_raw.encode())

    header_tags = doc_tree.find('.//tei:teiHeader', namespaces=NAMESPACES).iter()
    body_tags = doc_tree.find('.//tei:body', namespaces=NAMESPACES).iter()

    stats_df = pd.DataFrame(columns=['document', 'tag', 'tag_id', 'location', 'attr_name', 'attr_value'])

    tag_count = 0
    for tag in header_tags:
        for attr_name, attr_value in tag.items():
            stats_df.loc[len(stats_df)] = {
                'document': doc_name,
                'tag': tag.tag,
                'tag_id': doc_name + str(tag_count),
                'location': 'header',
                'attr_name': attr_name,
                'attr_value': attr_value
            }
        tag_count += 1
        
    for tag in body_tags:
        for attr_name, attr_value in tag.items():
            stats_df.loc[len(stats_df)] = {
                'document': doc_name,
                'tag': tag.tag,
                'tag_id': doc_name + str(tag_count),
                'location': 'body',
                'attr_name': attr_name,
                'attr_value': attr_value
            }
        tag_count += 1

    return stats_df

# %%
def create_summary_for_document_collection(doc_gen: Iterable[str])->pd.DataFrame: 
    stats_df = pd.DataFrame(columns=['document', 'tag', 'tag_id', 'location', 'attr_name', 'attr_value'])

    for doc, doc_name in tqdm(doc_gen):
        stats = create_summary_for_document(doc, doc_name)
        stats_df = stats_df.append(stats)

    return stats_df

# %%
get_latest_content = lambda f: f.versions \
        .latest('creation_date') \
        .get_content() \
        .split('<?xml version="1.0"?>')[1] \
        .strip()

file_gen = ((get_latest_content(file), file.name) for file in files)
stats_df = create_summary_for_document_collection(file_gen)
# Out:
# 26it [00:13,  1.95it/s]

# %%
def get_stats(stats_df):
    n_docs = len(stats_df['document'].unique())
    tag_g = stats_df.groupby('tag')
    tag_stats = tag_g.describe()
    attr_value_counts = stats_df \
            .loc[:,['tag','attr_name', 'attr_value']] \
            .groupby(['tag','attr_name']) \
            .attr_value \
            .value_counts()
    
    stats = ({
        'name': row[0],
        'count': row[1]['tag_id']['unique'],
        'coverage': 100*row[1]['document']['unique'] / n_docs,
        'n_docs': row[1]['document']['unique'],
        'location': row[1]['location']['top'],
        'attributes': tuple({
                'name': attr[0],
                'top_perc': 100*attr[1]['attr_value']['freq']/attr[1]['attr_value']['count'],
                'top_value': attr[1]['attr_value']['top'],
                'coverage': 100*attr[1]['document']['count']/row[1]['tag_id']['unique'],
                'distinct_values': attr_value_counts[row[0]][attr[0]].count(),
                'values': tuple(attr_value_counts[row[0]][attr[0]].head().to_dict().items())
            }for attr in tag_g.get_group(row[0]).groupby('attr_name').describe().iterrows())
    } for row in tag_stats.iterrows())
    
    return stats
    
tuple(get_stats(stats_df))
# Out:
# ({'name': 'include',
#   'count': 27,
#   'coverage': 100.0,
#   'n_docs': 26,
#   'location': 'header',
#   'attributes': ({'name': 'href',
#     'top_perc': 100.0,
#     'top_value': 'responsiblePeople.xml',
#     'coverage': 100.0,
#     'distinct_values': 1,
#     'values': (('responsiblePeople.xml', 27),)},
#    {'name': 'xpointer',
#     'top_perc': 96.29629629629629,
#     'top_value': 'RP5',
#     'coverage': 100.0,
#     'distinct_values': 2,
#     'values': (('RP5', 26), ('RP1', 1))})},
#  {'name': '{http://www.tei-c.org/ns/1.0}add',
#   'count': 170,
#   'coverage': 61.53846153846154,
#   'n_docs': 16,
#   'location': 'body',
#   'attributes': ({'name': 'place',
#     'top_perc': 100.0,
#     'top_value': 'inline',
#     'coverage': 100.0,
#     'distinct_values': 1,
#     'values': (('inline', 170),)},)},
#  {'name': '{http://www.tei-c.org/ns/1.0}certainty',
#   'count': 300,
#   'coverage': 73.07692307692308,
#   'n_docs': 19,
#   'location': 'header',
#   'attributes': ({'name': 'assertedValue',
#     'top_perc': 48.666666666666664,
#     'top_value': 'placeName',
#     'coverage': 100.0,
#     'distinct_values': 6,
#     'values': (('placeName', 146),
#      ('date', 106),
#      ('person', 36),
#      ('placename', 6),
#      ('organization', 5))},
#    {'name': 'category',
#     'top_perc': 100.0,
#     'top_value': 'incompleteness',
#     'coverage': 100.0,
#     'distinct_values': 1,
#     'values': (('incompleteness', 300),)},
#    {'name': 'cert',
#     'top_perc': 100.0,
#     'top_value': 'unknown',
#     'coverage': 100.0,
#     'distinct_values': 1,
#     'values': (('unknown', 300),)},
#    {'name': 'degree',
#     'top_perc': 25.0,
#     'top_value': '0.12',
#     'coverage': 100.0,
#     'distinct_values': 44,
#     'values': (('0.12', 75),
#      ('0.8', 62),
#      ('1.0', 18),
#      ('0.8571428571428572', 11),
#      ('0.10285714285714286', 9))},
#    {'name': 'desc',
#     'top_perc': 10.0,
#     'top_value': "Automatically annotated based on the initial annotation 'County of _strike_Meath_/strike_' from the document 'dep_834017r015_tei_(original_normalized_depositions_marked_persons).xml'. 2 out of 3 highly coincident terms. Normalized Levenshtein similarity between terms: (1.0, 1.0, 0.09090909090909094).",
#     'coverage': 100.0,
#     'distinct_values': 98,
#     'values': (("Automatically annotated based on the initial annotation 'County of _strike_Meath_/strike_' from the document 'dep_834017r015_tei_(original_normalized_depositions_marked_persons).xml'. 2 out of 3 highly coincident terms. Normalized Levenshtein similarity between terms: (1.0, 1.0, 0.09090909090909094).",
#       30),
#      ("Automatically annotated based on the initial annotation 'County of _strike_Meath_/strike_' from the document 'dep_834017r015_tei_(original_normalized_depositions_marked_persons).xml'. 2 out of 3 highly coincident terms. Normalized Levenshtein similarity between terms: (1.0, 1.0, 0.045454545454545414).",
#       20),
#      ("Automatically annotated based on the initial annotation 'Dublin' from the document 'dep_811203r142_tei_(original_normalized_depositions_marked_persons).xml'. 1 out of 1 highly coincident terms. Normalized Levenshtein similarity between terms: (0.8571428571428572,).",
#       11),
#      ('Automatically annotated based on high confidence in date match (May). Exact month match.',
#       9),
#      ("Automatically annotated based on the initial annotation '1643' from the document 'dep_814242r151_tei_(original_normalized_depositions_marked_persons).xml'. 1 out of 1 highly coincident terms. Normalized Levenshtein similarity between terms: (0.75,).",
#       9))},
#    {'name': 'locus',
#     'top_perc': 100.0,
#     'top_value': 'name',
#     'coverage': 100.0,
#     'distinct_values': 1,
#     'values': (('name', 300),)},
#    {'name': 'resp',
#     'top_perc': 100.0,
#     'top_value': '#automatic_gazeetter_ner',
#     'coverage': 100.0,
#     'distinct_values': 1,
#     'values': (('#automatic_gazeetter_ner', 300),)},
#    {'name': 'target',
#     'top_perc': 0.6666666666666666,
#     'top_value': '#placeName2682',
#     'coverage': 100.0,
#     'distinct_values': 275,
#     'values': (('#date2414', 2),
#      ('#m_date1873', 2),
#      ('#m_date1874', 2),
#      ('#m_date1951', 2),
#      ('#m_date1953', 2))})},
#  {'name': '{http://www.tei-c.org/ns/1.0}change',
#   'count': 26,
#   'coverage': 100.0,
#   'n_docs': 26,
#   'location': 'header',
#   'attributes': ({'name': 'when',
#     'top_perc': 3.8461538461538463,
#     'top_value': '2009-08-12T15:34:39',
#     'coverage': 100.0,
#     'distinct_values': 26,
#     'values': (('2009-08-12T11:53:07', 1),
#      ('2009-08-12T13:17:26', 1),
#      ('2009-08-12T13:28:04', 1),
#      ('2009-08-12T13:31:37', 1),
#      ('2009-08-12T13:36:19', 1))},
#    {'name': 'who',
#     'top_perc': 96.15384615384616,
#     'top_value': 'responsiblePeople.xml#RP5',
#     'coverage': 100.0,
#     'distinct_values': 2,
#     'values': (('responsiblePeople.xml#RP5', 25),
#      ('responsiblePeople.xml#RP1', 1))})},
#  {'name': '{http://www.tei-c.org/ns/1.0}classCode',
#   'count': 26,
#   'coverage': 100.0,
#   'n_docs': 26,
#   'location': 'header',
#   'attributes': ({'name': 'scheme',
#     'top_perc': 100.0,
#     'top_value': 'http://providedh.eu/uncertainty/ns/1.0',
#     'coverage': 100.0,
#     'distinct_values': 1,
#     'values': (('http://providedh.eu/uncertainty/ns/1.0', 26),)},)},
#  {'name': '{http://www.tei-c.org/ns/1.0}country',
#   'count': 20,
#   'coverage': 73.07692307692308,
#   'n_docs': 19,
#   'location': 'header',
#   'attributes': ({'name': 'key',
#     'top_perc': 100.0,
#     'top_value': 'IRL',
#     'coverage': 100.0,
#     'distinct_values': 1,
#     'values': (('IRL', 20),)},)},
#  {'name': '{http://www.tei-c.org/ns/1.0}date',
#   'count': 130,
#   'coverage': 96.15384615384616,
#   'n_docs': 25,
#   'location': 'body',
#   'attributes': ({'name': 'when',
#     'top_perc': 5.645161290322581,
#     'top_value': '1653',
#     'coverage': 95.38461538461539,
#     'distinct_values': 53,
#     'values': (('1641-10', 7),
#      ('1653', 7),
#      ('--05', 6),
#      ('1643', 6),
#      ('1652', 6))},
#    {'name': '{http://www.w3.org/XML/1998/namespace}id',
#     'top_perc': 1.8867924528301887,
#     'top_value': 'm_date1874',
#     'coverage': 81.53846153846153,
#     'distinct_values': 99,
#     'values': (('date2414', 2),
#      ('m_date1873', 2),
#      ('m_date1874', 2),
#      ('m_date1951', 2),
#      ('m_date1953', 2))})},
#  {'name': '{http://www.tei-c.org/ns/1.0}del',
#   'count': 219,
#   'coverage': 69.23076923076923,
#   'n_docs': 18,
#   'location': 'body',
#   'attributes': ({'name': 'rend',
#     'top_perc': 100.0,
#     'top_value': 'strikethrough',
#     'coverage': 100.0,
#     'distinct_values': 1,
#     'values': (('strikethrough', 219),)},)},
#  {'name': '{http://www.tei-c.org/ns/1.0}div',
#   'count': 78,
#   'coverage': 100.0,
#   'n_docs': 26,
#   'location': 'body',
#   'attributes': ({'name': 'type',
#     'top_perc': 33.333333333333336,
#     'top_value': 'deposition',
#     'coverage': 100.0,
#     'distinct_values': 3,
#     'values': (('deposition', 26), ('normalised', 26), ('original', 26))},)},
#  {'name': '{http://www.tei-c.org/ns/1.0}event',
#   'count': 1,
#   'coverage': 3.8461538461538463,
#   'n_docs': 1,
#   'location': 'body',
#   'attributes': ({'name': '{http://www.w3.org/XML/1998/namespace}id',
#     'top_perc': 100.0,
#     'top_value': 'event0077',
#     'coverage': 100.0,
#     'distinct_values': 1,
#     'values': (('event0077', 1),)},)},
#  {'name': '{http://www.tei-c.org/ns/1.0}include',
#   'count': 26,
#   'coverage': 100.0,
#   'n_docs': 26,
#   'location': 'header',
#   'attributes': ({'name': 'href',
#     'top_perc': 100.0,
#     'top_value': 'manuscriptDescription_tei.xml',
#     'coverage': 100.0,
#     'distinct_values': 1,
#     'values': (('manuscriptDescription_tei.xml', 26),)},
#    {'name': 'xpointer',
#     'top_perc': 100.0,
#     'top_value': 'ms839',
#     'coverage': 100.0,
#     'distinct_values': 1,
#     'values': (('ms839', 26),)})},
#  {'name': '{http://www.tei-c.org/ns/1.0}keywords',
#   'count': 47,
#   'coverage': 100.0,
#   'n_docs': 26,
#   'location': 'header',
#   'attributes': ({'name': 'scheme',
#     'top_perc': 100.0,
#     'top_value': '1641',
#     'coverage': 100.0,
#     'distinct_values': 1,
#     'values': (('1641', 47),)},)},
#  {'name': '{http://www.tei-c.org/ns/1.0}language',
#   'count': 26,
#   'coverage': 100.0,
#   'n_docs': 26,
#   'location': 'header',
#   'attributes': ({'name': 'ident',
#     'top_perc': 100.0,
#     'top_value': 'en',
#     'coverage': 100.0,
#     'distinct_values': 1,
#     'values': (('en', 26),)},
#    {'name': 'usage',
#     'top_perc': 100.0,
#     'top_value': '100',
#     'coverage': 100.0,
#     'distinct_values': 1,
#     'values': (('100', 26),)})},
#  {'name': '{http://www.tei-c.org/ns/1.0}list',
#   'count': 47,
#   'coverage': 100.0,
#   'n_docs': 26,
#   'location': 'header',
#   'attributes': ({'name': 'type',
#     'top_perc': 55.319148936170215,
#     'top_value': 'deposition_type',
#     'coverage': 100.0,
#     'distinct_values': 2,
#     'values': (('deposition_type', 26), ('nature_of_deposition', 21))},)},
#  {'name': '{http://www.tei-c.org/ns/1.0}listPerson',
#   'count': 26,
#   'coverage': 100.0,
#   'n_docs': 26,
#   'location': 'header',
#   'attributes': ({'name': 'type',
#     'top_perc': 100.0,
#     'top_value': 'PROVIDEDH Annotators',
#     'coverage': 100.0,
#     'distinct_values': 1,
#     'values': (('PROVIDEDH Annotators', 26),)},)},
#  {'name': '{http://www.tei-c.org/ns/1.0}note',
#   'count': 76,
#   'coverage': 69.23076923076923,
#   'n_docs': 18,
#   'location': 'body',
#   'attributes': ({'name': 'type',
#     'top_perc': 100.0,
#     'top_value': 'marginalia',
#     'coverage': 100.0,
#     'distinct_values': 1,
#     'values': (('marginalia', 76),)},)},
#  {'name': '{http://www.tei-c.org/ns/1.0}organization',
#   'count': 5,
#   'coverage': 7.6923076923076925,
#   'n_docs': 2,
#   'location': 'body',
#   'attributes': ({'name': '{http://www.w3.org/XML/1998/namespace}id',
#     'top_perc': 20.0,
#     'top_value': 'm_organization0311',
#     'coverage': 100.0,
#     'distinct_values': 5,
#     'values': (('m_organization0310', 1),
#      ('m_organization0311', 1),
#      ('m_organization0312', 1),
#      ('organization0392', 1),
#      ('organization0393', 1))},)},
#  {'name': '{http://www.tei-c.org/ns/1.0}pb',
#   'count': 187,
#   'coverage': 100.0,
#   'n_docs': 26,
#   'location': 'body',
#   'attributes': ({'name': 'n',
#     'top_perc': 3.2085561497326203,
#     'top_value': 'fol. 143v',
#     'coverage': 100.0,
#     'distinct_values': 60,
#     'values': (('fol. 126v', 6),
#      ('fol. 143v', 6),
#      ('fol. 144v', 6),
#      ('fol. 132v', 4),
#      ('fol. 102r', 3))},
#    {'name': 'pagenum',
#     'top_perc': 2.4,
#     'top_value': '1732',
#     'coverage': 66.84491978609626,
#     'distinct_values': 42,
#     'values': (('1206', 3),
#      ('1217', 3),
#      ('1218', 3),
#      ('1224', 3),
#      ('1225', 3))})},
#  {'name': '{http://www.tei-c.org/ns/1.0}person',
#   'count': 678,
#   'coverage': 100.0,
#   'n_docs': 26,
#   'location': 'body',
#   'attributes': ({'name': 'sameAs',
#     'top_perc': 3.982300884955752,
#     'top_value': 'person839147r102-4',
#     'coverage': 66.66666666666667,
#     'distinct_values': 127,
#     'values': (('person839147r102-4', 18),
#      ('person839102r069-12', 12),
#      ('person839105r072-2', 12),
#      ('person839147r102-1', 12),
#      ('person839104r071-1', 9))},
#    {'name': 'sex',
#     'top_perc': 54.8780487804878,
#     'top_value': '3',
#     'coverage': 24.188790560471976,
#     'distinct_values': 3,
#     'values': (('3', 90), ('1', 65), ('2', 9))},
#    {'name': '{http://www.w3.org/XML/1998/namespace}id',
#     'top_perc': 11.504424778761061,
#     'top_value': 'automatic_gazeetter_ner',
#     'coverage': 33.333333333333336,
#     'distinct_values': 200,
#     'values': (('automatic_gazeetter_ner', 26),
#      ('m_person0444', 2),
#      ('m_person0426', 1),
#      ('m_person0427', 1),
#      ('m_person0428', 1))})},
#  {'name': '{http://www.tei-c.org/ns/1.0}place',
#   'count': 3,
#   'coverage': 11.538461538461538,
#   'n_docs': 3,
#   'location': 'header',
#   'attributes': ({'name': '{http://www.w3.org/XML/1998/namespace}id',
#     'top_perc': 33.333333333333336,
#     'top_value': 'place839102r069-1',
#     'coverage': 100.0,
#     'distinct_values': 3,
#     'values': (('place839102r069-1', 1),
#      ('place839115r078-1', 1),
#      ('place839118r080-1', 1))},)},
#  {'name': '{http://www.tei-c.org/ns/1.0}placeName',
#   'count': 161,
#   'coverage': 73.07692307692308,
#   'n_docs': 19,
#   'location': 'body',
#   'attributes': ({'name': 'type',
#     'top_perc': 93.33333333333333,
#     'top_value': 'Placename',
#     'coverage': 9.316770186335404,
#     'distinct_values': 2,
#     'values': (('Placename', 14), ('', 1))},
#    {'name': '{http://www.w3.org/XML/1998/namespace}id',
#     'top_perc': 1.36986301369863,
#     'top_value': 'm_placeName2138',
#     'coverage': 90.6832298136646,
#     'distinct_values': 131,
#     'values': (('m_placeName2045', 2),
#      ('m_placeName2046', 2),
#      ('m_placeName2047', 2),
#      ('m_placeName2048', 2),
#      ('m_placeName2049', 2))})},
#  {'name': '{http://www.tei-c.org/ns/1.0}placename',
#   'count': 9,
#   'coverage': 15.384615384615385,
#   'n_docs': 4,
#   'location': 'body',
#   'attributes': ({'name': 'type',
#     'top_perc': 66.66666666666667,
#     'top_value': 'Placename',
#     'coverage': 33.333333333333336,
#     'distinct_values': 2,
#     'values': (('Placename', 2), ('City', 1))},
#    {'name': '{http://www.w3.org/XML/1998/namespace}id',
#     'top_perc': 33.333333333333336,
#     'top_value': 'm_placename0026',
#     'coverage': 66.66666666666667,
#     'distinct_values': 4,
#     'values': (('m_placename0025', 2),
#      ('m_placename0026', 2),
#      ('m_placename0027', 1),
#      ('m_placename0028', 1))})},
#  {'name': '{http://www.tei-c.org/ns/1.0}region',
#   'count': 20,
#   'coverage': 73.07692307692308,
#   'n_docs': 19,
#   'location': 'header',
#   'attributes': ({'name': 'type',
#     'top_perc': 100.0,
#     'top_value': 'County',
#     'coverage': 100.0,
#     'distinct_values': 1,
#     'values': (('County', 20),)},)},
#  {'name': '{http://www.tei-c.org/ns/1.0}roleName',
#   'count': 238,
#   'coverage': 76.92307692307692,
#   'n_docs': 20,
#   'location': 'header',
#   'attributes': ({'name': 'type',
#     'top_perc': 31.932773109243698,
#     'top_value': 'Commissioner',
#     'coverage': 100.0,
#     'distinct_values': 9,
#     'values': (('Commissioner', 76),
#      ('Rebel', 57),
#      ('Victim', 37),
#      ('Mentioned', 28),
#      ('Deponent', 24))},)},
#  {'name': '{http://www.tei-c.org/ns/1.0}rolename',
#   'count': 37,
#   'coverage': 69.23076923076923,
#   'n_docs': 18,
#   'location': 'body',
#   'attributes': ({'name': 'type',
#     'top_perc': 100.0,
#     'top_value': 'commissioner',
#     'coverage': 100.0,
#     'distinct_values': 1,
#     'values': (('commissioner', 37),)},)},
#  {'name': '{http://www.tei-c.org/ns/1.0}surname',
#   'count': 2,
#   'coverage': 7.6923076923076925,
#   'n_docs': 2,
#   'location': 'header',
#   'attributes': ({'name': 'type',
#     'top_perc': 100.0,
#     'top_value': 'Patronym',
#     'coverage': 100.0,
#     'distinct_values': 1,
#     'values': (('Patronym', 2),)},)},
#  {'name': '{http://www.tei-c.org/ns/1.0}unclear',
#   'count': 60,
#   'coverage': 53.84615384615385,
#   'n_docs': 14,
#   'location': 'body',
#   'attributes': ({'name': 'reason',
#     'top_perc': 100.0,
#     'top_value': 'illegible',
#     'coverage': 100.0,
#     'distinct_values': 1,
#     'values': (('illegible', 60),)},)},
#  {'name': '{http://www.w3.org/2001/XInclude}include',
#   'count': 125,
#   'coverage': 100.0,
#   'n_docs': 26,
#   'location': 'header',
#   'attributes': ({'name': 'href',
#     'top_perc': 58.4,
#     'top_value': 'keywords.xml',
#     'coverage': 100.0,
#     'distinct_values': 3,
#     'values': (('keywords.xml', 73),
#      ('editorialDecl.xml', 26),
#      ('projectDesc.xml', 26))},
#    {'name': 'xpointer',
#     'top_perc': 20.8,
#     'top_value': 'id1641-editorialDecl',
#     'coverage': 100.0,
#     'distinct_values': 18,
#     'values': (('id1641-editorialDecl', 26),
#      ('id1641-projectDesc', 26),
#      ('dt3', 12),
#      ('nod101', 9),
#      ('nod5', 9))})})

# %%
def create_fast_stats_for_document_collection(doc_gen: Iterable[str])->pd.DataFrame: 
    stats_df = pd.DataFrame(columns=['body', 'header', 'count', 'attr_count'])

    for doc, doc_name in tqdm(doc_gen):
        doc_tree = et.fromstring(doc.encode())

        header_tags = doc_tree.find('.//tei:teiHeader', namespaces=NAMESPACES).iter()
        body_tags = doc_tree.find('.//tei:body', namespaces=NAMESPACES).iter()
        

        for tag in header_tags:
            try:
                if not tag.tag in stats_df.index:
                    stats_df.loc[tag.tag] = {
                        'body': 0,
                        'header': 1,
                        'count': 1,
                        'attr_count': len(tag.keys()),
                    }
                else:
                    stats_df.loc[tag.tag] = {
                        'body': stats_df.loc[tag.tag, 'body'],
                        'header': stats_df.loc[tag.tag, 'header'] + 1,
                        'count': stats_df.loc[tag.tag, 'header'] + 1,
                        'attr_count': stats_df.loc[tag.tag, 'attr_count'] + len(tag.keys()),
                    }
            except Exception:
                pass

        for tag in body_tags:
            try:
                if not tag.tag in stats_df.index:
                    stats_df.loc[tag.tag] = {
                        'body': 1,
                        'header': 0,
                        'count': 1,
                        'attr_count': len(tag.keys()),
                    }
                else:
                    stats_df.loc[tag.tag] = {
                        'body': stats_df.loc[tag.tag, 'body'] + 1,
                        'header': stats_df.loc[tag.tag, 'header'],
                        'count': stats_df.loc[tag.tag, 'header'] + 1,
                        'attr_count': stats_df.loc[tag.tag, 'attr_count'] + len(tag.keys()),
                    }
            except Exception:
                pass
    
    most_common = stats_df.sort_values('count', ascending=False).iloc[:4] 
    most_common['tag'] = most_common.index
    most_common['attr_count'] = most_common['attr_count'] / most_common['count']

    return most_common.to_dict(orient='records')

# %%
get_latest_content = lambda f: f.versions \
        .latest('creation_date') \
        .get_content() \
        .split('<?xml version="1.0"?>')[1] \
        .strip()

file_gen = ((get_latest_content(file), file.name) for file in files)
create_fast_stats_for_document_collection(file_gen)
# Out:
# 44it [00:06,  6.36it/s]
# [{'body': 0,
#   'header': 603,
#   'count': 603,
#   'attr_count': 8.0,
#   'tag': '{http://www.tei-c.org/ns/1.0}certainty'},
#  {'body': 0,
#   'header': 340,
#   'count': 340,
#   'attr_count': 0.047058823529411764,
#   'tag': '{http://www.tei-c.org/ns/1.0}surname'},
#  {'body': 960,
#   'header': 324,
#   'count': 325,
#   'attr_count': 4.812307692307693,
#   'tag': '{http://www.tei-c.org/ns/1.0}person'},
#  {'body': 0,
#   'header': 324,
#   'count': 324,
#   'attr_count': 0.0,
#   'tag': '{http://www.tei-c.org/ns/1.0}persName'}]

# %%
x = stats_df.loc[:,['tag','attr_name', 'attr_value']].groupby(['tag','attr_name']).attr_value.value_counts()

# %%
head = x['include']['href'].head()

# %%
x['{http://www.tei-c.org/ns/1.0}date']['when'].count()
# Out:
# 53

# %%
list(head.items())
# Out:
# [('1641-10', 7), ('1653', 7), ('--05', 6), ('1643', 6), ('1652', 6)]

# %%
def get_fast_stats(stats_df):
    most_common = tag.sort_values('count', ascending=False).iloc[:3]
    
    stats = ({
        'name': row[0].split('}')[1] if '}' in row[0] else row[0],
        'count': row[1]['count'],
        'header': 
        'coverage': 100*row[1]['document']['unique'] / n_docs,
        'n_docs': row[1]['document']['unique'],
        'location': row[1]['location']['top'],
        'attributes': tuple({
                'name': attr[0],
                'top_perc': 100*attr[1]['attr_value']['freq']/attr[1]['attr_value']['count'],
                'top_value': attr[1]['attr_value']['top'],
                'coverage': 100*attr[1]['document']['count']/row[1]['tag_id']['unique'],
                'values': []
            }for attr in tag_g.get_group(row[0]).groupby('attr_name').describe().iterrows())
    } for row in most_common.iterrows())
    
    return stats
    
tuple(get_stats(stats_df))

# %%
from typing import Iterable

from django.contrib.auth.decorators import login_required
from django.http import HttpRequest, HttpResponse
from django.shortcuts import render

from apps.views_decorators import objects_exists, user_has_access
from apps.files_management.models import File, FileVersion
from apps.projects.models import Project

from django.db.models import Q

import pandas as pd
from lxml import etree as et
from tqdm import tqdm

# %%
NAMESPACES = {'tei': 'http://www.tei-c.org/ns/1.0', 'xml': 'http://www.w3.org/XML/1998/namespace'}

# %%
project = Project.objects.get(title__exact='p')
files_query = Q(project=project)
files = File.objects.filter(files_query)

# %%
file = files[0] 
file.name
# Out:
# 'dep_839064r043_tei_(original_normalized_depositions_marked_persons_gazetteer_gazetteer_date_annotation).xml'

# %%
content = get_latest_content(file)

# %%
def create_summary_for_document(doc_raw: str, doc_name:str='undefined')->pd.DataFrame: 
    doc_tree = et.fromstring(doc_raw.encode())

    header_tags = doc_tree.find('.//tei:teiHeader', namespaces=NAMESPACES).iter()
    body_tags = doc_tree.find('.//tei:body', namespaces=NAMESPACES).iter()

    stats_df = pd.DataFrame(columns=['document', 'tag', 'tag_id', 'location', 'attr_name', 'attr_value'])

    tag_count = 0
    for tag in header_tags:
        for attr_name, attr_value in tag.items():
            stats_df.loc[len(stats_df)] = {
                'document': doc_name,
                'tag': tag.tag,
                'tag_id': doc_name + str(tag_count),
                'location': 'header',
                'attr_name': attr_name,
                'attr_value': attr_value
            }
        tag_count += 1
        
    for tag in body_tags:
        for attr_name, attr_value in tag.items():
            stats_df.loc[len(stats_df)] = {
                'document': doc_name,
                'tag': tag.tag,
                'tag_id': doc_name + str(tag_count),
                'location': 'body',
                'attr_name': attr_name,
                'attr_value': attr_value
            }
        tag_count += 1

    return stats_df

# %%
def create_summary_for_document_collection(doc_gen: Iterable[str])->pd.DataFrame: 
    stats_df = pd.DataFrame(columns=['document', 'tag', 'tag_id', 'location', 'attr_name', 'attr_value'])

    for doc, doc_name in tqdm(doc_gen):
        stats = create_summary_for_document(doc, doc_name)
        stats_df = stats_df.append(stats)

    return stats_df

# %%
get_latest_content = lambda f: f.versions \
        .latest('creation_date') \
        .get_content() \
        .split('<?xml version="1.0"?>')[1] \
        .strip()

file_gen = ((get_latest_content(file), file.name) for file in files)
stats_df = create_summary_for_document_collection(file_gen)
# Out:
# 44it [00:24,  1.80it/s]

# %%
def get_stats(stats_df):
    n_docs = len(stats_df['document'].unique())
    tag_g = stats_df.groupby('tag')
    tag_stats = tag_g.describe()
    
    stats = ({
        'name': row[0],
        'count': row[1]['tag_id']['unique'],
        'coverage': 100*row[1]['document']['unique'] / n_docs,
        'n_docs': row[1]['document']['unique'],
        'location': row[1]['location']['top'],
        'attributes': tuple({
                'name': attr[0],
                'top_perc': 100*attr[1]['attr_value']['freq']/attr[1]['attr_value']['count'],
                'top_value': attr[1]['attr_value']['top'],
                'coverage': 100*attr[1]['document']['count']/row[1]['tag_id']['unique'],
                'values': []
            }for attr in tag_g.get_group(row[0]).groupby('attr_name').describe().iterrows())
    } for row in tag_stats.iterrows())
    
    return stats
    
tuple(get_stats(stats_df))
# Out:
# ({'name': 'include',
#   'count': 45,
#   'coverage': 100.0,
#   'location': 'header',
#   'attributes': ({'name': 'href',
#     'top_perc': 100.0,
#     'top_value': 'responsiblePeople.xml',
#     'coverage': 100.0,
#     'values': []},
#    {'name': 'xpointer',
#     'top_perc': 97.77777777777777,
#     'top_value': 'RP5',
#     'coverage': 100.0,
#     'values': []})},
#  {'name': '{http://www.tei-c.org/ns/1.0}add',
#   'count': 346,
#   'coverage': 72.72727272727273,
#   'location': 'body',
#   'attributes': ({'name': 'place',
#     'top_perc': 100.0,
#     'top_value': 'inline',
#     'coverage': 100.0,
#     'values': []},)},
#  {'name': '{http://www.tei-c.org/ns/1.0}certainty',
#   'count': 603,
#   'coverage': 81.81818181818181,
#   'location': 'header',
#   'attributes': ({'name': 'assertedValue',
#     'top_perc': 37.81094527363184,
#     'top_value': 'date',
#     'coverage': 100.0,
#     'values': []},
#    {'name': 'category',
#     'top_perc': 100.0,
#     'top_value': 'incompletness',
#     'coverage': 100.0,
#     'values': []},
#    {'name': 'cert',
#     'top_perc': 100.0,
#     'top_value': 'unknown',
#     'coverage': 100.0,
#     'values': []},
#    {'name': 'degree',
#     'top_perc': 22.388059701492537,
#     'top_value': '0.8',
#     'coverage': 100.0,
#     'values': []},
#    {'name': 'desc',
#     'top_perc': 6.301824212271973,
#     'top_value': "Automatically annotated based on the initial annotation '1643' from the document 'dep_814242r151_tei_(original_normalized_depositions_marked_persons).xml'. 1 out of 1 highly coincident terms. Normalized Levenshtein similarity between terms: (0.75,).",
#     'coverage': 100.0,
#     'values': []},
#    {'name': 'locus',
#     'top_perc': 100.0,
#     'top_value': 'name',
#     'coverage': 100.0,
#     'values': []},
#    {'name': 'resp',
#     'top_perc': 100.0,
#     'top_value': '#automatic_gazeetter_ner',
#     'coverage': 100.0,
#     'values': []},
#    {'name': 'target',
#     'top_perc': 0.6633499170812603,
#     'top_value': '#m_person0476',
#     'coverage': 100.0,
#     'values': []})},
#  {'name': '{http://www.tei-c.org/ns/1.0}change',
#   'count': 44,
#   'coverage': 100.0,
#   'location': 'header',
#   'attributes': ({'name': 'when',
#     'top_perc': 2.272727272727273,
#     'top_value': '2009-08-13T10:05:15',
#     'coverage': 100.0,
#     'values': []},
#    {'name': 'who',
#     'top_perc': 97.72727272727273,
#     'top_value': 'responsiblePeople.xml#RP5',
#     'coverage': 100.0,
#     'values': []})},
#  {'name': '{http://www.tei-c.org/ns/1.0}classCode',
#   'count': 44,
#   'coverage': 100.0,
#   'location': 'header',
#   'attributes': ({'name': 'scheme',
#     'top_perc': 100.0,
#     'top_value': 'http://providedh.eu/uncertainty/ns/1.0',
#     'coverage': 100.0,
#     'values': []},)},
#  {'name': '{http://www.tei-c.org/ns/1.0}country',
#   'count': 36,
#   'coverage': 81.81818181818181,
#   'location': 'header',
#   'attributes': ({'name': 'key',
#     'top_perc': 100.0,
#     'top_value': 'IRL',
#     'coverage': 100.0,
#     'values': []},)},
#  {'name': '{http://www.tei-c.org/ns/1.0}date',
#   'count': 269,
#   'coverage': 95.45454545454545,
#   'location': 'body',
#   'attributes': ({'name': 'when',
#     'top_perc': 13.654618473895582,
#     'top_value': '1641',
#     'coverage': 92.56505576208178,
#     'values': []},
#    {'name': '{http://www.w3.org/XML/1998/namespace}id',
#     'top_perc': 1.3157894736842106,
#     'top_value': 'm_date1890',
#     'coverage': 84.75836431226766,
#     'values': []})},
#  {'name': '{http://www.tei-c.org/ns/1.0}del',
#   'count': 375,
#   'coverage': 77.27272727272727,
#   'location': 'body',
#   'attributes': ({'name': 'rend',
#     'top_perc': 96.8,
#     'top_value': 'strikethrough',
#     'coverage': 100.0,
#     'values': []},)},
#  {'name': '{http://www.tei-c.org/ns/1.0}div',
#   'count': 131,
#   'coverage': 100.0,
#   'location': 'body',
#   'attributes': ({'name': 'type',
#     'top_perc': 33.587786259541986,
#     'top_value': 'deposition',
#     'coverage': 100.0,
#     'values': []},)},
#  {'name': '{http://www.tei-c.org/ns/1.0}event',
#   'count': 3,
#   'coverage': 4.545454545454546,
#   'location': 'body',
#   'attributes': ({'name': '{http://www.w3.org/XML/1998/namespace}id',
#     'top_perc': 33.333333333333336,
#     'top_value': 'm_event0073',
#     'coverage': 100.0,
#     'values': []},)},
#  {'name': '{http://www.tei-c.org/ns/1.0}include',
#   'count': 44,
#   'coverage': 100.0,
#   'location': 'header',
#   'attributes': ({'name': 'href',
#     'top_perc': 100.0,
#     'top_value': 'manuscriptDescription_tei.xml',
#     'coverage': 100.0,
#     'values': []},
#    {'name': 'xpointer',
#     'top_perc': 100.0,
#     'top_value': 'ms839',
#     'coverage': 100.0,
#     'values': []})},
#  {'name': '{http://www.tei-c.org/ns/1.0}keywords',
#   'count': 83,
#   'coverage': 100.0,
#   'location': 'header',
#   'attributes': ({'name': 'scheme',
#     'top_perc': 100.0,
#     'top_value': '1641',
#     'coverage': 100.0,
#     'values': []},)},
#  {'name': '{http://www.tei-c.org/ns/1.0}language',
#   'count': 44,
#   'coverage': 100.0,
#   'location': 'header',
#   'attributes': ({'name': 'ident',
#     'top_perc': 100.0,
#     'top_value': 'en',
#     'coverage': 100.0,
#     'values': []},
#    {'name': 'usage',
#     'top_perc': 100.0,
#     'top_value': '100',
#     'coverage': 100.0,
#     'values': []})},
#  {'name': '{http://www.tei-c.org/ns/1.0}list',
#   'count': 83,
#   'coverage': 100.0,
#   'location': 'header',
#   'attributes': ({'name': 'type',
#     'top_perc': 53.01204819277108,
#     'top_value': 'deposition_type',
#     'coverage': 100.0,
#     'values': []},)},
#  {'name': '{http://www.tei-c.org/ns/1.0}listPerson',
#   'count': 44,
#   'coverage': 100.0,
#   'location': 'header',
#   'attributes': ({'name': 'type',
#     'top_perc': 100.0,
#     'top_value': 'PROVIDEDH Annotators',
#     'coverage': 100.0,
#     'values': []},)},
#  {'name': '{http://www.tei-c.org/ns/1.0}note',
#   'count': 158,
#   'coverage': 75.0,
#   'location': 'body',
#   'attributes': ({'name': 'type',
#     'top_perc': 100.0,
#     'top_value': 'marginalia',
#     'coverage': 100.0,
#     'values': []},)},
#  {'name': '{http://www.tei-c.org/ns/1.0}organization',
#   'count': 26,
#   'coverage': 13.636363636363637,
#   'location': 'body',
#   'attributes': ({'name': '{http://www.w3.org/XML/1998/namespace}id',
#     'top_perc': 11.538461538461538,
#     'top_value': 'm_organization0323',
#     'coverage': 100.0,
#     'values': []},)},
#  {'name': '{http://www.tei-c.org/ns/1.0}pb',
#   'count': 347,
#   'coverage': 100.0,
#   'location': 'body',
#   'attributes': ({'name': 'n',
#     'top_perc': 1.7291066282420748,
#     'top_value': 'fol. 126v',
#     'coverage': 100.0,
#     'values': []},
#    {'name': 'pagenum',
#     'top_perc': 2.5,
#     'top_value': '3409',
#     'coverage': 69.164265129683,
#     'values': []})},
#  {'name': '{http://www.tei-c.org/ns/1.0}person',
#   'count': 1284,
#   'coverage': 100.0,
#   'location': 'body',
#   'attributes': ({'name': 'sameAs',
#     'top_perc': 3.2181168057210967,
#     'top_value': 'person839070r047-2',
#     'coverage': 65.34267912772586,
#     'values': []},
#    {'name': 'sex',
#     'top_perc': 56.785714285714285,
#     'top_value': '3',
#     'coverage': 21.806853582554517,
#     'values': []},
#    {'name': '{http://www.w3.org/XML/1998/namespace}id',
#     'top_perc': 9.887640449438202,
#     'top_value': 'automatic_gazeetter_ner',
#     'coverage': 34.65732087227414,
#     'values': []})},
#  {'name': '{http://www.tei-c.org/ns/1.0}place',
#   'count': 8,
#   'coverage': 13.636363636363637,
#   'location': 'header',
#   'attributes': ({'name': '{http://www.w3.org/XML/1998/namespace}id',
#     'top_perc': 12.5,
#     'top_value': 'place839118r080-1',
#     'coverage': 100.0,
#     'values': []},)},
#  {'name': '{http://www.tei-c.org/ns/1.0}placeName',
#   'count': 235,
#   'coverage': 77.27272727272727,
#   'location': 'body',
#   'attributes': ({'name': 'type',
#     'top_perc': 96.15384615384616,
#     'top_value': 'Placename',
#     'coverage': 11.063829787234043,
#     'values': []},
#    {'name': '{http://www.w3.org/XML/1998/namespace}id',
#     'top_perc': 1.4354066985645932,
#     'top_value': 'm_placeName2164',
#     'coverage': 88.93617021276596,
#     'values': []})},
#  {'name': '{http://www.tei-c.org/ns/1.0}placename',
#   'count': 16,
#   'coverage': 13.636363636363637,
#   'location': 'body',
#   'attributes': ({'name': 'type',
#     'top_perc': 75.0,
#     'top_value': 'Placename',
#     'coverage': 25.0,
#     'values': []},
#    {'name': '{http://www.w3.org/XML/1998/namespace}id',
#     'top_perc': 16.666666666666668,
#     'top_value': 'm_placename0026',
#     'coverage': 75.0,
#     'values': []})},
#  {'name': '{http://www.tei-c.org/ns/1.0}region',
#   'count': 36,
#   'coverage': 81.81818181818181,
#   'location': 'header',
#   'attributes': ({'name': 'type',
#     'top_perc': 100.0,
#     'top_value': 'County',
#     'coverage': 100.0,
#     'values': []},)},
#  {'name': '{http://www.tei-c.org/ns/1.0}roleName',
#   'count': 425,
#   'coverage': 84.0909090909091,
#   'location': 'header',
#   'attributes': ({'name': 'type',
#     'top_perc': 34.588235294117645,
#     'top_value': 'Commissioner',
#     'coverage': 100.0,
#     'values': []},)},
#  {'name': '{http://www.tei-c.org/ns/1.0}rolename',
#   'count': 74,
#   'coverage': 79.54545454545455,
#   'location': 'body',
#   'attributes': ({'name': 'type',
#     'top_perc': 100.0,
#     'top_value': 'commissioner',
#     'coverage': 100.0,
#     'values': []},)},
#  {'name': '{http://www.tei-c.org/ns/1.0}surname',
#   'count': 16,
#   'coverage': 36.36363636363637,
#   'location': 'header',
#   'attributes': ({'name': 'type',
#     'top_perc': 100.0,
#     'top_value': 'Patronym',
#     'coverage': 100.0,
#     'values': []},)},
#  {'name': '{http://www.tei-c.org/ns/1.0}unclear',
#   'count': 102,
#   'coverage': 54.54545454545455,
#   'location': 'body',
#   'attributes': ({'name': 'reason',
#     'top_perc': 100.0,
#     'top_value': 'illegible',
#     'coverage': 100.0,
#     'values': []},)},
#  {'name': '{http://www.w3.org/2001/XInclude}include',
#   'count': 228,
#   'coverage': 100.0,
#   'location': 'header',
#   'attributes': ({'name': 'href',
#     'top_perc': 61.40350877192982,
#     'top_value': 'keywords.xml',
#     'coverage': 100.0,
#     'values': []},
#    {'name': 'xpointer',
#     'top_perc': 19.29824561403509,
#     'top_value': 'id1641-projectDesc',
#     'coverage': 100.0,
#     'values': []})})

# %%
len(stats_df['document'].unique())
# Out:
# 44

# %%
stats_df.groupby('tag_id').describe()
# Out:
#        document                                                            \
#           count unique                                                top
# tag_id
# 9            88     44  dep_839072r048_tei_(original_normalized_deposi...
# 12            2      1  dep_839106r073_tei_(original_normalized_deposi...
# 14           86     43  dep_839072r048_tei_(original_normalized_deposi...
# 17           88     44  dep_839072r048_tei_(original_normalized_deposi...
# 18           86     43  dep_839072r048_tei_(original_normalized_deposi...
# ...         ...    ...                                                ...
# 644           1      1  dep_839096r065_tei_(original_normalized_deposi...
# 650           2      1  dep_839096r065_tei_(original_normalized_deposi...
# 657           2      1  dep_839096r065_tei_(original_normalized_deposi...
# 666           1      1  dep_839096r065_tei_(original_normalized_deposi...
# 669           1      1  dep_839096r065_tei_(original_normalized_deposi...
#
#               tag                                                        \
#        freq count unique                                       top freq
# tag_id
# 9         2    88      1                                   include   88
# 12        2     2      1                                   include    2
# 14        2    86      1      {http://www.tei-c.org/ns/1.0}include   86
# 17        2    88      2  {http://www.w3.org/2001/XInclude}include   86
# 18        2    86      1  {http://www.w3.org/2001/XInclude}include   86
# ...     ...   ...    ...                                       ...  ...
# 644       1     1      1       {http://www.tei-c.org/ns/1.0}person    1
# 650       2     2      1           {http://www.tei-c.org/ns/1.0}pb    2
# 657       2     2      1         {http://www.tei-c.org/ns/1.0}date    2
# 666       1     1      1     {http://www.tei-c.org/ns/1.0}rolename    1
# 669       1     1      1     {http://www.tei-c.org/ns/1.0}rolename    1
#
#        location                     attr_name         \
#           count unique     top freq     count unique
# tag_id
# 9            88      1  header   88        88      2
# 12            2      1  header    2         2      2
# 14           86      1  header   86        86      2
# 17           88      1  header   88        88      2
# 18           86      1  header   86        86      2
# ...         ...    ...     ...  ...       ...    ...
# 644           1      1    body    1         1      1
# 650           2      1    body    2         2      2
# 657           2      1    body    2         2      2
# 666           1      1    body    1         1      1
# 669           1      1    body    1         1      1
#
#                                                       attr_value         \
#                                              top freq      count unique
# tag_id
# 9                                       xpointer   44         88      3
# 12                                      xpointer    1          2      2
# 14                                      xpointer   43         86      2
# 17                                      xpointer   44         88      4
# 18                                      xpointer   43         86      2
# ...                                          ...  ...        ...    ...
# 644                                       sameAs    1          1      1
# 650                                      pagenum    1          2      2
# 657     {http://www.w3.org/XML/1998/namespace}id    1          2      2
# 666                                         type    1          1      1
# 669                                         type    1          1      1
#
#
#                           top freq
# tag_id
# 9       responsiblePeople.xml   44
# 12                        RP5    1
# 14                      ms839   43
# 17            projectDesc.xml   43
# 18       id1641-editorialDecl   43
# ...                       ...  ...
# 644        person839096r065-1    1
# 650                  fol. 97v    1
# 657                 1643-06-2    1
# 666              commissioner    1
# 669              commissioner    1
#
# [606 rows x 20 columns]

# %%
tuple(
    {
        'name': attr[0],
        'top_perc': 100*attr[1]['attr_value']['freq']/attr[1]['attr_value']['count'],
        'top_value': attr[1]['attr_value']['top'],
        'coverage': attr[1]['document']['count'],
        'values': []
    }
    for attr in tag_g.get_group('{http://www.tei-c.org/ns/1.0}certainty').groupby('attr_name').describe().iterrows())
# Out:
# ({'name': 'assertedValue',
#   'top_perc': 37.81094527363184,
#   'top_value': 'date',
#   'coverage': 603,
#   'values': []},
#  {'name': 'category',
#   'top_perc': 100.0,
#   'top_value': 'incompletness',
#   'coverage': 603,
#   'values': []},
#  {'name': 'cert',
#   'top_perc': 100.0,
#   'top_value': 'unknown',
#   'coverage': 603,
#   'values': []},
#  {'name': 'degree',
#   'top_perc': 22.388059701492537,
#   'top_value': '0.8',
#   'coverage': 603,
#   'values': []},
#  {'name': 'desc',
#   'top_perc': 6.301824212271973,
#   'top_value': "Automatically annotated based on the initial annotation '1643' from the document 'dep_814242r151_tei_(original_normalized_depositions_marked_persons).xml'. 1 out of 1 highly coincident terms. Normalized Levenshtein similarity between terms: (0.75,).",
#   'coverage': 603,
#   'values': []},
#  {'name': 'locus',
#   'top_perc': 100.0,
#   'top_value': 'name',
#   'coverage': 603,
#   'values': []},
#  {'name': 'resp',
#   'top_perc': 100.0,
#   'top_value': '#automatic_gazeetter_ner',
#   'coverage': 603,
#   'values': []},
#  {'name': 'target',
#   'top_perc': 0.6633499170812603,
#   'top_value': '#m_person0476',
#   'coverage': 603,
#   'values': []})

# %%
g = stats_df.groupby('tag')
for key, item in g:
    print(g.get_group(key), "\n\n")
# Out:
#                                              document      tag location  \
# 0   dep_839064r043_tei_(original_normalized_deposi...  include   header
# 1   dep_839064r043_tei_(original_normalized_deposi...  include   header
# 0   dep_839060r041_tei_(original_normalized_deposi...  include   header
# 1   dep_839060r041_tei_(original_normalized_deposi...  include   header
# 0   dep_839066r044_tei_(original_normalized_deposi...  include   header
# ..                                                ...      ...      ...
# 1   dep_839145r101_tei_(original_normalized_deposi...  include   header
# 0   dep_839147r102_tei_(original_normalized_deposi...  include   header
# 1   dep_839147r102_tei_(original_normalized_deposi...  include   header
# 0   dep_839149r103_tei_(original_normalized_deposi...  include   header
# 1   dep_839149r103_tei_(original_normalized_deposi...  include   header
#
#    attr_name             attr_value
# 0       href  responsiblePeople.xml
# 1   xpointer                    RP5
# 0       href  responsiblePeople.xml
# 1   xpointer                    RP5
# 0       href  responsiblePeople.xml
# ..       ...                    ...
# 1   xpointer                    RP5
# 0       href  responsiblePeople.xml
# 1   xpointer                    RP5
# 0       href  responsiblePeople.xml
# 1   xpointer                    RP5
#
# [90 rows x 5 columns]
#
#
#                                               document  \
# 205  dep_839064r043_tei_(original_normalized_deposi...
# 207  dep_839064r043_tei_(original_normalized_deposi...
# 208  dep_839064r043_tei_(original_normalized_deposi...
# 219  dep_839064r043_tei_(original_normalized_deposi...
# 234  dep_839064r043_tei_(original_normalized_deposi...
# ..                                                 ...
# 276  dep_839145r101_tei_(original_normalized_deposi...
# 302  dep_839145r101_tei_(original_normalized_deposi...
# 303  dep_839145r101_tei_(original_normalized_deposi...
# 679  dep_839147r102_tei_(original_normalized_deposi...
# 752  dep_839147r102_tei_(original_normalized_deposi...
#
#                                   tag location attr_name attr_value
# 205  {http://www.tei-c.org/ns/1.0}add     body     place     inline
# 207  {http://www.tei-c.org/ns/1.0}add     body     place     inline
# 208  {http://www.tei-c.org/ns/1.0}add     body     place     inline
# 219  {http://www.tei-c.org/ns/1.0}add     body     place     inline
# 234  {http://www.tei-c.org/ns/1.0}add     body     place     inline
# ..                                ...      ...       ...        ...
# 276  {http://www.tei-c.org/ns/1.0}add     body     place     inline
# 302  {http://www.tei-c.org/ns/1.0}add     body     place     inline
# 303  {http://www.tei-c.org/ns/1.0}add     body     place     inline
# 679  {http://www.tei-c.org/ns/1.0}add     body     place     inline
# 752  {http://www.tei-c.org/ns/1.0}add     body     place     inline
#
# [346 rows x 5 columns]
#
#
#                                               document  \
# 20   dep_839064r043_tei_(original_normalized_deposi...
# 21   dep_839064r043_tei_(original_normalized_deposi...
# 22   dep_839064r043_tei_(original_normalized_deposi...
# 23   dep_839064r043_tei_(original_normalized_deposi...
# 24   dep_839064r043_tei_(original_normalized_deposi...
# ..                                                 ...
# 103  dep_839149r103_tei_(original_normalized_deposi...
# 104  dep_839149r103_tei_(original_normalized_deposi...
# 105  dep_839149r103_tei_(original_normalized_deposi...
# 106  dep_839149r103_tei_(original_normalized_deposi...
# 107  dep_839149r103_tei_(original_normalized_deposi...
#
#                                         tag location      attr_name  \
# 20   {http://www.tei-c.org/ns/1.0}certainty   header       category
# 21   {http://www.tei-c.org/ns/1.0}certainty   header          locus
# 22   {http://www.tei-c.org/ns/1.0}certainty   header         degree
# 23   {http://www.tei-c.org/ns/1.0}certainty   header           cert
# 24   {http://www.tei-c.org/ns/1.0}certainty   header           resp
# ..                                      ...      ...            ...
# 103  {http://www.tei-c.org/ns/1.0}certainty   header           cert
# 104  {http://www.tei-c.org/ns/1.0}certainty   header           resp
# 105  {http://www.tei-c.org/ns/1.0}certainty   header         target
# 106  {http://www.tei-c.org/ns/1.0}certainty   header           desc
# 107  {http://www.tei-c.org/ns/1.0}certainty   header  assertedValue
#
#                                             attr_value
# 20                                       incompletness
# 21                                                name
# 22                                 0.18881118881118877
# 23                                             unknown
# 24                            #automatic_gazeetter_ner
# ..                                                 ...
# 103                                            unknown
# 104                           #automatic_gazeetter_ner
# 105                                        #m_date2414
# 106  Automatically annotated based on low confidenc...
# 107                                               date
#
# [4824 rows x 5 columns]
#
#
#                                               document  \
# 170  dep_839064r043_tei_(original_normalized_deposi...
# 171  dep_839064r043_tei_(original_normalized_deposi...
# 233  dep_839060r041_tei_(original_normalized_deposi...
# 234  dep_839060r041_tei_(original_normalized_deposi...
# 117  dep_839066r044_tei_(original_normalized_deposi...
# ..                                                 ...
# 229  dep_839145r101_tei_(original_normalized_deposi...
# 578  dep_839147r102_tei_(original_normalized_deposi...
# 579  dep_839147r102_tei_(original_normalized_deposi...
# 128  dep_839149r103_tei_(original_normalized_deposi...
# 129  dep_839149r103_tei_(original_normalized_deposi...
#
#                                      tag location attr_name  \
# 170  {http://www.tei-c.org/ns/1.0}change   header      when
# 171  {http://www.tei-c.org/ns/1.0}change   header       who
# 233  {http://www.tei-c.org/ns/1.0}change   header      when
# 234  {http://www.tei-c.org/ns/1.0}change   header       who
# 117  {http://www.tei-c.org/ns/1.0}change   header      when
# ..                                   ...      ...       ...
# 229  {http://www.tei-c.org/ns/1.0}change   header       who
# 578  {http://www.tei-c.org/ns/1.0}change   header      when
# 579  {http://www.tei-c.org/ns/1.0}change   header       who
# 128  {http://www.tei-c.org/ns/1.0}change   header      when
# 129  {http://www.tei-c.org/ns/1.0}change   header       who
#
#                     attr_value
# 170        2009-08-11T11:31:26
# 171  responsiblePeople.xml#RP5
# 233        2009-08-11T11:09:48
# 234  responsiblePeople.xml#RP5
# 117        2009-08-11T11:34:15
# ..                         ...
# 229  responsiblePeople.xml#RP5
# 578        2009-08-13T12:57:55
# 579  responsiblePeople.xml#RP5
# 128        2009-08-13T13:05:41
# 129  responsiblePeople.xml#RP5
#
# [88 rows x 5 columns]
#
#
#                                              document  \
# 19  dep_839064r043_tei_(original_normalized_deposi...
# 25  dep_839060r041_tei_(original_normalized_deposi...
# 19  dep_839066r044_tei_(original_normalized_deposi...
# 21  dep_839066r045_tei_(original_normalized_deposi...
# 21  dep_839068r046_tei_(original_normalized_deposi...
# 19  dep_839070r047_tei_(original_normalized_deposi...
# 21  dep_839072r048_tei_(original_normalized_deposi...
# 21  dep_839074r049_tei_(original_normalized_deposi...
# 21  dep_839080r052_tei_(original_normalized_deposi...
# 19  dep_839082r053_tei_(original_normalized_deposi...
# 21  dep_839084r054_tei_(original_normalized_deposi...
# 17  dep_839085r055_tei_(original_normalized_deposi...
# 21  dep_839085r056_tei_(original_normalized_deposi...
# 19  dep_839085v057_tei_(original_normalized_deposi...
# 15  dep_839085v058_tei_(original_normalized_deposi...
# 21  dep_839087r059_tei_(original_normalized_deposi...
# 21  dep_839088r060_tei_(original_normalized_deposi...
# 21  dep_839090r061_tei_(original_normalized_deposi...
# 16  dep_839093r063_tei_(original_normalized_deposi...
# 21  dep_839095r064_tei_(original_normalized_deposi...
# 25  dep_839096r065_tei_(original_normalized_deposi...
# 23  dep_839098r066_tei_(original_normalized_deposi...
# 19  dep_839099r067_tei_(original_normalized_deposi...
# 19  dep_839102r069_tei_(original_normalized_deposi...
# 17  dep_839103r070_tei_(original_normalized_deposi...
# 17  dep_839105r072_tei_(original_normalized_deposi...
# 17  dep_839104r071_tei_(original_normalized_deposi...
# 25  dep_839106r073_tei_(original_normalized_deposi...
# 21  dep_839118r080_tei_(original_normalized_deposi...
# 21  dep_839122r082_tei_(original_normalized_deposi...
# 19  dep_839123r083_tei_(original_normalized_deposi...
# 16  dep_839124r084_tei_(original_normalized_deposi...
# 13  dep_839125r085_tei_(original_normalized_deposi...
# 13  dep_839125v086_tei_(original_normalized_deposi...
# 13  dep_839126v087_tei_(original_normalized_deposi...
# 13  dep_839127v088_tei_(original_normalized_deposi...
# 13  dep_839132r091_tei_(original_normalized_deposi...
# 26  dep_839136r094_tei_(original_normalized_deposi...
# 19  dep_839141r097_tei_(original_normalized_deposi...
# 17  dep_839143v099_tei_(original_normalized_deposi...
# 17  dep_839143v100_tei_(original_normalized_deposi...
# 19  dep_839145r101_tei_(original_normalized_deposi...
# 21  dep_839147r102_tei_(original_normalized_deposi...
# 19  dep_839149r103_tei_(original_normalized_deposi...
#
#                                        tag location attr_name  \
# 19  {http://www.tei-c.org/ns/1.0}classCode   header    scheme
# 25  {http://www.tei-c.org/ns/1.0}classCode   header    scheme
# 19  {http://www.tei-c.org/ns/1.0}classCode   header    scheme
# 21  {http://www.tei-c.org/ns/1.0}classCode   header    scheme
# 21  {http://www.tei-c.org/ns/1.0}classCode   header    scheme
# 19  {http://www.tei-c.org/ns/1.0}classCode   header    scheme
# 21  {http://www.tei-c.org/ns/1.0}classCode   header    scheme
# 21  {http://www.tei-c.org/ns/1.0}classCode   header    scheme
# 21  {http://www.tei-c.org/ns/1.0}classCode   header    scheme
# 19  {http://www.tei-c.org/ns/1.0}classCode   header    scheme
# 21  {http://www.tei-c.org/ns/1.0}classCode   header    scheme
# 17  {http://www.tei-c.org/ns/1.0}classCode   header    scheme
# 21  {http://www.tei-c.org/ns/1.0}classCode   header    scheme
# 19  {http://www.tei-c.org/ns/1.0}classCode   header    scheme
# 15  {http://www.tei-c.org/ns/1.0}classCode   header    scheme
# 21  {http://www.tei-c.org/ns/1.0}classCode   header    scheme
# 21  {http://www.tei-c.org/ns/1.0}classCode   header    scheme
# 21  {http://www.tei-c.org/ns/1.0}classCode   header    scheme
# 16  {http://www.tei-c.org/ns/1.0}classCode   header    scheme
# 21  {http://www.tei-c.org/ns/1.0}classCode   header    scheme
# 25  {http://www.tei-c.org/ns/1.0}classCode   header    scheme
# 23  {http://www.tei-c.org/ns/1.0}classCode   header    scheme
# 19  {http://www.tei-c.org/ns/1.0}classCode   header    scheme
# 19  {http://www.tei-c.org/ns/1.0}classCode   header    scheme
# 17  {http://www.tei-c.org/ns/1.0}classCode   header    scheme
# 17  {http://www.tei-c.org/ns/1.0}classCode   header    scheme
# 17  {http://www.tei-c.org/ns/1.0}classCode   header    scheme
# 25  {http://www.tei-c.org/ns/1.0}classCode   header    scheme
# 21  {http://www.tei-c.org/ns/1.0}classCode   header    scheme
# 21  {http://www.tei-c.org/ns/1.0}classCode   header    scheme
# 19  {http://www.tei-c.org/ns/1.0}classCode   header    scheme
# 16  {http://www.tei-c.org/ns/1.0}classCode   header    scheme
# 13  {http://www.tei-c.org/ns/1.0}classCode   header    scheme
# 13  {http://www.tei-c.org/ns/1.0}classCode   header    scheme
# 13  {http://www.tei-c.org/ns/1.0}classCode   header    scheme
# 13  {http://www.tei-c.org/ns/1.0}classCode   header    scheme
# 13  {http://www.tei-c.org/ns/1.0}classCode   header    scheme
# 26  {http://www.tei-c.org/ns/1.0}classCode   header    scheme
# 19  {http://www.tei-c.org/ns/1.0}classCode   header    scheme
# 17  {http://www.tei-c.org/ns/1.0}classCode   header    scheme
# 17  {http://www.tei-c.org/ns/1.0}classCode   header    scheme
# 19  {http://www.tei-c.org/ns/1.0}classCode   header    scheme
# 21  {http://www.tei-c.org/ns/1.0}classCode   header    scheme
# 19  {http://www.tei-c.org/ns/1.0}classCode   header    scheme
#
#                                 attr_value
# 19  http://providedh.eu/uncertainty/ns/1.0
# 25  http://providedh.eu/uncertainty/ns/1.0
# 19  http://providedh.eu/uncertainty/ns/1.0
# 21  http://providedh.eu/uncertainty/ns/1.0
# 21  http://providedh.eu/uncertainty/ns/1.0
# 19  http://providedh.eu/uncertainty/ns/1.0
# 21  http://providedh.eu/uncertainty/ns/1.0
# 21  http://providedh.eu/uncertainty/ns/1.0
# 21  http://providedh.eu/uncertainty/ns/1.0
# 19  http://providedh.eu/uncertainty/ns/1.0
# 21  http://providedh.eu/uncertainty/ns/1.0
# 17  http://providedh.eu/uncertainty/ns/1.0
# 21  http://providedh.eu/uncertainty/ns/1.0
# 19  http://providedh.eu/uncertainty/ns/1.0
# 15  http://providedh.eu/uncertainty/ns/1.0
# 21  http://providedh.eu/uncertainty/ns/1.0
# 21  http://providedh.eu/uncertainty/ns/1.0
# 21  http://providedh.eu/uncertainty/ns/1.0
# 16  http://providedh.eu/uncertainty/ns/1.0
# 21  http://providedh.eu/uncertainty/ns/1.0
# 25  http://providedh.eu/uncertainty/ns/1.0
# 23  http://providedh.eu/uncertainty/ns/1.0
# 19  http://providedh.eu/uncertainty/ns/1.0
# 19  http://providedh.eu/uncertainty/ns/1.0
# 17  http://providedh.eu/uncertainty/ns/1.0
# 17  http://providedh.eu/uncertainty/ns/1.0
# 17  http://providedh.eu/uncertainty/ns/1.0
# 25  http://providedh.eu/uncertainty/ns/1.0
# 21  http://providedh.eu/uncertainty/ns/1.0
# 21  http://providedh.eu/uncertainty/ns/1.0
# 19  http://providedh.eu/uncertainty/ns/1.0
# 16  http://providedh.eu/uncertainty/ns/1.0
# 13  http://providedh.eu/uncertainty/ns/1.0
# 13  http://providedh.eu/uncertainty/ns/1.0
# 13  http://providedh.eu/uncertainty/ns/1.0
# 13  http://providedh.eu/uncertainty/ns/1.0
# 13  http://providedh.eu/uncertainty/ns/1.0
# 26  http://providedh.eu/uncertainty/ns/1.0
# 19  http://providedh.eu/uncertainty/ns/1.0
# 17  http://providedh.eu/uncertainty/ns/1.0
# 17  http://providedh.eu/uncertainty/ns/1.0
# 19  http://providedh.eu/uncertainty/ns/1.0
# 21  http://providedh.eu/uncertainty/ns/1.0
# 19  http://providedh.eu/uncertainty/ns/1.0
#
#
#                                               document  \
# 146  dep_839064r043_tei_(original_normalized_deposi...
# 224  dep_839060r041_tei_(original_normalized_deposi...
# 75   dep_839066r044_tei_(original_normalized_deposi...
# 93   dep_839066r045_tei_(original_normalized_deposi...
# 108  dep_839068r046_tei_(original_normalized_deposi...
# 99   dep_839070r047_tei_(original_normalized_deposi...
# 108  dep_839072r048_tei_(original_normalized_deposi...
# 204  dep_839074r049_tei_(original_normalized_deposi...
# 117  dep_839080r052_tei_(original_normalized_deposi...
# 171  dep_839082r053_tei_(original_normalized_deposi...
# 180  dep_839084r054_tei_(original_normalized_deposi...
# 121  dep_839085r055_tei_(original_normalized_deposi...
# 165  dep_839085r056_tei_(original_normalized_deposi...
# 147  dep_839085v057_tei_(original_normalized_deposi...
# 111  dep_839085v058_tei_(original_normalized_deposi...
# 173  dep_839087r059_tei_(original_normalized_deposi...
# 149  dep_839088r060_tei_(original_normalized_deposi...
# 164  dep_839090r061_tei_(original_normalized_deposi...
# 125  dep_839095r064_tei_(original_normalized_deposi...
# 585  dep_839096r065_tei_(original_normalized_deposi...
# 111  dep_839098r066_tei_(original_normalized_deposi...
# 115  dep_839099r067_tei_(original_normalized_deposi...
# 339  dep_839102r069_tei_(original_normalized_deposi...
# 25   dep_839103r070_tei_(original_normalized_deposi...
# 89   dep_839105r072_tei_(original_normalized_deposi...
# 113  dep_839104r071_tei_(original_normalized_deposi...
# 152  dep_839106r073_tei_(original_normalized_deposi...
# 133  dep_839118r080_tei_(original_normalized_deposi...
# 125  dep_839122r082_tei_(original_normalized_deposi...
# 90   dep_839123r083_tei_(original_normalized_deposi...
# 322  dep_839136r094_tei_(original_normalized_deposi...
# 83   dep_839141r097_tei_(original_normalized_deposi...
# 25   dep_839143v099_tei_(original_normalized_deposi...
# 33   dep_839143v100_tei_(original_normalized_deposi...
# 500  dep_839147r102_tei_(original_normalized_deposi...
# 115  dep_839149r103_tei_(original_normalized_deposi...
#
#                                       tag location attr_name attr_value
# 146  {http://www.tei-c.org/ns/1.0}country   header       key        IRL
# 224  {http://www.tei-c.org/ns/1.0}country   header       key        IRL
# 75   {http://www.tei-c.org/ns/1.0}country   header       key        IRL
# 93   {http://www.tei-c.org/ns/1.0}country   header       key        IRL
# 108  {http://www.tei-c.org/ns/1.0}country   header       key        IRL
# 99   {http://www.tei-c.org/ns/1.0}country   header       key        IRL
# 108  {http://www.tei-c.org/ns/1.0}country   header       key        IRL
# 204  {http://www.tei-c.org/ns/1.0}country   header       key        IRL
# 117  {http://www.tei-c.org/ns/1.0}country   header       key        IRL
# 171  {http://www.tei-c.org/ns/1.0}country   header       key        IRL
# 180  {http://www.tei-c.org/ns/1.0}country   header       key        IRL
# 121  {http://www.tei-c.org/ns/1.0}country   header       key        IRL
# 165  {http://www.tei-c.org/ns/1.0}country   header       key        IRL
# 147  {http://www.tei-c.org/ns/1.0}country   header       key        IRL
# 111  {http://www.tei-c.org/ns/1.0}country   header       key        IRL
# 173  {http://www.tei-c.org/ns/1.0}country   header       key        IRL
# 149  {http://www.tei-c.org/ns/1.0}country   header       key        IRL
# 164  {http://www.tei-c.org/ns/1.0}country   header       key        IRL
# 125  {http://www.tei-c.org/ns/1.0}country   header       key        IRL
# 585  {http://www.tei-c.org/ns/1.0}country   header       key        IRL
# 111  {http://www.tei-c.org/ns/1.0}country   header       key        IRL
# 115  {http://www.tei-c.org/ns/1.0}country   header       key        IRL
# 339  {http://www.tei-c.org/ns/1.0}country   header       key        IRL
# 25   {http://www.tei-c.org/ns/1.0}country   header       key        IRL
# 89   {http://www.tei-c.org/ns/1.0}country   header       key        IRL
# 113  {http://www.tei-c.org/ns/1.0}country   header       key        IRL
# 152  {http://www.tei-c.org/ns/1.0}country   header       key        IRL
# 133  {http://www.tei-c.org/ns/1.0}country   header       key        IRL
# 125  {http://www.tei-c.org/ns/1.0}country   header       key        IRL
# 90   {http://www.tei-c.org/ns/1.0}country   header       key        IRL
# 322  {http://www.tei-c.org/ns/1.0}country   header       key        IRL
# 83   {http://www.tei-c.org/ns/1.0}country   header       key        IRL
# 25   {http://www.tei-c.org/ns/1.0}country   header       key        IRL
# 33   {http://www.tei-c.org/ns/1.0}country   header       key        IRL
# 500  {http://www.tei-c.org/ns/1.0}country   header       key        IRL
# 115  {http://www.tei-c.org/ns/1.0}country   header       key        IRL
#
#
#                                               document  \
# 8    dep_839064r043_tei_(original_normalized_deposi...
# 180  dep_839064r043_tei_(original_normalized_deposi...
# 181  dep_839064r043_tei_(original_normalized_deposi...
# 182  dep_839064r043_tei_(original_normalized_deposi...
# 195  dep_839064r043_tei_(original_normalized_deposi...
# ..                                                 ...
# 144  dep_839149r103_tei_(original_normalized_deposi...
# 165  dep_839149r103_tei_(original_normalized_deposi...
# 166  dep_839149r103_tei_(original_normalized_deposi...
# 167  dep_839149r103_tei_(original_normalized_deposi...
# 168  dep_839149r103_tei_(original_normalized_deposi...
#
#                                    tag location  \
# 8    {http://www.tei-c.org/ns/1.0}date   header
# 180  {http://www.tei-c.org/ns/1.0}date     body
# 181  {http://www.tei-c.org/ns/1.0}date     body
# 182  {http://www.tei-c.org/ns/1.0}date     body
# 195  {http://www.tei-c.org/ns/1.0}date     body
# ..                                 ...      ...
# 144  {http://www.tei-c.org/ns/1.0}date     body
# 165  {http://www.tei-c.org/ns/1.0}date     body
# 166  {http://www.tei-c.org/ns/1.0}date     body
# 167  {http://www.tei-c.org/ns/1.0}date     body
# 168  {http://www.tei-c.org/ns/1.0}date     body
#
#                                     attr_name  attr_value
# 8                                        when   1653_4_19
# 180  {http://www.w3.org/XML/1998/namespace}id  m_date1969
# 181                                      when        1653
# 182  {http://www.w3.org/XML/1998/namespace}id  m_date1965
# 195  {http://www.w3.org/XML/1998/namespace}id  m_date1970
# ..                                        ...         ...
# 144                                      when        1641
# 165  {http://www.w3.org/XML/1998/namespace}id  m_date2412
# 166                                      when     1652-02
# 167  {http://www.w3.org/XML/1998/namespace}id  m_date2413
# 168                                      when        1641
#
# [477 rows x 5 columns]
#
#
#                                               document  \
# 202  dep_839064r043_tei_(original_normalized_deposi...
# 206  dep_839064r043_tei_(original_normalized_deposi...
# 210  dep_839064r043_tei_(original_normalized_deposi...
# 214  dep_839064r043_tei_(original_normalized_deposi...
# 216  dep_839064r043_tei_(original_normalized_deposi...
# ..                                                 ...
# 157  dep_839149r103_tei_(original_normalized_deposi...
# 158  dep_839149r103_tei_(original_normalized_deposi...
# 171  dep_839149r103_tei_(original_normalized_deposi...
# 178  dep_839149r103_tei_(original_normalized_deposi...
# 179  dep_839149r103_tei_(original_normalized_deposi...
#
#                                   tag location attr_name     attr_value
# 202  {http://www.tei-c.org/ns/1.0}del     body      rend  strikethrough
# 206  {http://www.tei-c.org/ns/1.0}del     body      rend  strikethrough
# 210  {http://www.tei-c.org/ns/1.0}del     body      rend  strikethrough
# 214  {http://www.tei-c.org/ns/1.0}del     body      rend  strikethrough
# 216  {http://www.tei-c.org/ns/1.0}del     body      rend  strikethrough
# ..                                ...      ...       ...            ...
# 157  {http://www.tei-c.org/ns/1.0}del     body      rend  strikethrough
# 158  {http://www.tei-c.org/ns/1.0}del     body      rend  strikethrough
# 171  {http://www.tei-c.org/ns/1.0}del     body      rend  strikethrough
# 178  {http://www.tei-c.org/ns/1.0}del     body      rend  strikethrough
# 179  {http://www.tei-c.org/ns/1.0}del     body      rend  strikethrough
#
# [375 rows x 5 columns]
#
#
#                                               document  \
# 172  dep_839064r043_tei_(original_normalized_deposi...
# 199  dep_839064r043_tei_(original_normalized_deposi...
# 235  dep_839060r041_tei_(original_normalized_deposi...
# 255  dep_839060r041_tei_(original_normalized_deposi...
# 293  dep_839060r041_tei_(original_normalized_deposi...
# ..                                                 ...
# 644  dep_839147r102_tei_(original_normalized_deposi...
# 719  dep_839147r102_tei_(original_normalized_deposi...
# 130  dep_839149r103_tei_(original_normalized_deposi...
# 136  dep_839149r103_tei_(original_normalized_deposi...
# 161  dep_839149r103_tei_(original_normalized_deposi...
#
#                                   tag location attr_name  attr_value
# 172  {http://www.tei-c.org/ns/1.0}div     body      type  deposition
# 199  {http://www.tei-c.org/ns/1.0}div     body      type  normalised
# 235  {http://www.tei-c.org/ns/1.0}div     body      type  deposition
# 255  {http://www.tei-c.org/ns/1.0}div     body      type    original
# 293  {http://www.tei-c.org/ns/1.0}div     body      type  normalised
# ..                                ...      ...       ...         ...
# 644  {http://www.tei-c.org/ns/1.0}div     body      type    original
# 719  {http://www.tei-c.org/ns/1.0}div     body      type  normalised
# 130  {http://www.tei-c.org/ns/1.0}div     body      type  deposition
# 136  {http://www.tei-c.org/ns/1.0}div     body      type    original
# 161  {http://www.tei-c.org/ns/1.0}div     body      type  normalised
#
# [131 rows x 5 columns]
#
#
#                                               document  \
# 769  dep_839096r065_tei_(original_normalized_deposi...
# 917  dep_839096r065_tei_(original_normalized_deposi...
# 200  dep_839099r067_tei_(original_normalized_deposi...
#
#                                     tag location  \
# 769  {http://www.tei-c.org/ns/1.0}event     body
# 917  {http://www.tei-c.org/ns/1.0}event     body
# 200  {http://www.tei-c.org/ns/1.0}event     body
#
#                                     attr_name   attr_value
# 769  {http://www.w3.org/XML/1998/namespace}id  m_event0072
# 917  {http://www.w3.org/XML/1998/namespace}id  m_event0073
# 200  {http://www.w3.org/XML/1998/namespace}id  m_event0077
#
#
#                                              document  \
# 2   dep_839064r043_tei_(original_normalized_deposi...
# 3   dep_839064r043_tei_(original_normalized_deposi...
# 2   dep_839060r041_tei_(original_normalized_deposi...
# 3   dep_839060r041_tei_(original_normalized_deposi...
# 2   dep_839066r044_tei_(original_normalized_deposi...
# ..                                                ...
# 3   dep_839145r101_tei_(original_normalized_deposi...
# 2   dep_839147r102_tei_(original_normalized_deposi...
# 3   dep_839147r102_tei_(original_normalized_deposi...
# 2   dep_839149r103_tei_(original_normalized_deposi...
# 3   dep_839149r103_tei_(original_normalized_deposi...
#
#                                      tag location attr_name  \
# 2   {http://www.tei-c.org/ns/1.0}include   header      href
# 3   {http://www.tei-c.org/ns/1.0}include   header  xpointer
# 2   {http://www.tei-c.org/ns/1.0}include   header      href
# 3   {http://www.tei-c.org/ns/1.0}include   header  xpointer
# 2   {http://www.tei-c.org/ns/1.0}include   header      href
# ..                                   ...      ...       ...
# 3   {http://www.tei-c.org/ns/1.0}include   header  xpointer
# 2   {http://www.tei-c.org/ns/1.0}include   header      href
# 3   {http://www.tei-c.org/ns/1.0}include   header  xpointer
# 2   {http://www.tei-c.org/ns/1.0}include   header      href
# 3   {http://www.tei-c.org/ns/1.0}include   header  xpointer
#
#                        attr_value
# 2   manuscriptDescription_tei.xml
# 3                           ms839
# 2   manuscriptDescription_tei.xml
# 3                           ms839
# 2   manuscriptDescription_tei.xml
# ..                            ...
# 3                           ms839
# 2   manuscriptDescription_tei.xml
# 3                           ms839
# 2   manuscriptDescription_tei.xml
# 3                           ms839
#
# [88 rows x 5 columns]
#
#
#                                              document  \
# 9   dep_839064r043_tei_(original_normalized_deposi...
# 13  dep_839064r043_tei_(original_normalized_deposi...
# 9   dep_839060r041_tei_(original_normalized_deposi...
# 13  dep_839060r041_tei_(original_normalized_deposi...
# 9   dep_839066r044_tei_(original_normalized_deposi...
# ..                                                ...
# 13  dep_839145r101_tei_(original_normalized_deposi...
# 9   dep_839147r102_tei_(original_normalized_deposi...
# 13  dep_839147r102_tei_(original_normalized_deposi...
# 9   dep_839149r103_tei_(original_normalized_deposi...
# 13  dep_839149r103_tei_(original_normalized_deposi...
#
#                                       tag location attr_name attr_value
# 9   {http://www.tei-c.org/ns/1.0}keywords   header    scheme       1641
# 13  {http://www.tei-c.org/ns/1.0}keywords   header    scheme       1641
# 9   {http://www.tei-c.org/ns/1.0}keywords   header    scheme       1641
# 13  {http://www.tei-c.org/ns/1.0}keywords   header    scheme       1641
# 9   {http://www.tei-c.org/ns/1.0}keywords   header    scheme       1641
# ..                                    ...      ...       ...        ...
# 13  {http://www.tei-c.org/ns/1.0}keywords   header    scheme       1641
# 9   {http://www.tei-c.org/ns/1.0}keywords   header    scheme       1641
# 13  {http://www.tei-c.org/ns/1.0}keywords   header    scheme       1641
# 9   {http://www.tei-c.org/ns/1.0}keywords   header    scheme       1641
# 13  {http://www.tei-c.org/ns/1.0}keywords   header    scheme       1641
#
# [83 rows x 5 columns]
#
#
#                                               document  \
# 140  dep_839064r043_tei_(original_normalized_deposi...
# 141  dep_839064r043_tei_(original_normalized_deposi...
# 218  dep_839060r041_tei_(original_normalized_deposi...
# 219  dep_839060r041_tei_(original_normalized_deposi...
# 68   dep_839066r044_tei_(original_normalized_deposi...
# ..                                                 ...
# 189  dep_839145r101_tei_(original_normalized_deposi...
# 494  dep_839147r102_tei_(original_normalized_deposi...
# 495  dep_839147r102_tei_(original_normalized_deposi...
# 108  dep_839149r103_tei_(original_normalized_deposi...
# 109  dep_839149r103_tei_(original_normalized_deposi...
#
#                                        tag location attr_name attr_value
# 140  {http://www.tei-c.org/ns/1.0}language   header     ident         en
# 141  {http://www.tei-c.org/ns/1.0}language   header     usage        100
# 218  {http://www.tei-c.org/ns/1.0}language   header     ident         en
# 219  {http://www.tei-c.org/ns/1.0}language   header     usage        100
# 68   {http://www.tei-c.org/ns/1.0}language   header     ident         en
# ..                                     ...      ...       ...        ...
# 189  {http://www.tei-c.org/ns/1.0}language   header     usage        100
# 494  {http://www.tei-c.org/ns/1.0}language   header     ident         en
# 495  {http://www.tei-c.org/ns/1.0}language   header     usage        100
# 108  {http://www.tei-c.org/ns/1.0}language   header     ident         en
# 109  {http://www.tei-c.org/ns/1.0}language   header     usage        100
#
# [88 rows x 5 columns]
#
#
#                                              document  \
# 10  dep_839064r043_tei_(original_normalized_deposi...
# 14  dep_839064r043_tei_(original_normalized_deposi...
# 10  dep_839060r041_tei_(original_normalized_deposi...
# 14  dep_839060r041_tei_(original_normalized_deposi...
# 10  dep_839066r044_tei_(original_normalized_deposi...
# ..                                                ...
# 14  dep_839145r101_tei_(original_normalized_deposi...
# 10  dep_839147r102_tei_(original_normalized_deposi...
# 14  dep_839147r102_tei_(original_normalized_deposi...
# 10  dep_839149r103_tei_(original_normalized_deposi...
# 14  dep_839149r103_tei_(original_normalized_deposi...
#
#                                   tag location attr_name            attr_value
# 10  {http://www.tei-c.org/ns/1.0}list   header      type       deposition_type
# 14  {http://www.tei-c.org/ns/1.0}list   header      type  nature_of_deposition
# 10  {http://www.tei-c.org/ns/1.0}list   header      type       deposition_type
# 14  {http://www.tei-c.org/ns/1.0}list   header      type  nature_of_deposition
# 10  {http://www.tei-c.org/ns/1.0}list   header      type       deposition_type
# ..                                ...      ...       ...                   ...
# 14  {http://www.tei-c.org/ns/1.0}list   header      type  nature_of_deposition
# 10  {http://www.tei-c.org/ns/1.0}list   header      type       deposition_type
# 14  {http://www.tei-c.org/ns/1.0}list   header      type  nature_of_deposition
# 10  {http://www.tei-c.org/ns/1.0}list   header      type       deposition_type
# 14  {http://www.tei-c.org/ns/1.0}list   header      type  nature_of_deposition
#
# [83 rows x 5 columns]
#
#
#                                               document  \
# 168  dep_839064r043_tei_(original_normalized_deposi...
# 231  dep_839060r041_tei_(original_normalized_deposi...
# 113  dep_839066r044_tei_(original_normalized_deposi...
# 118  dep_839066r045_tei_(original_normalized_deposi...
# 116  dep_839068r046_tei_(original_normalized_deposi...
# 122  dep_839070r047_tei_(original_normalized_deposi...
# 133  dep_839072r048_tei_(original_normalized_deposi...
# 227  dep_839074r049_tei_(original_normalized_deposi...
# 137  dep_839080r052_tei_(original_normalized_deposi...
# 194  dep_839082r053_tei_(original_normalized_deposi...
# 188  dep_839084r054_tei_(original_normalized_deposi...
# 129  dep_839085r055_tei_(original_normalized_deposi...
# 176  dep_839085r056_tei_(original_normalized_deposi...
# 152  dep_839085v057_tei_(original_normalized_deposi...
# 116  dep_839085v058_tei_(original_normalized_deposi...
# 187  dep_839087r059_tei_(original_normalized_deposi...
# 163  dep_839088r060_tei_(original_normalized_deposi...
# 178  dep_839090r061_tei_(original_normalized_deposi...
# 19   dep_839093r063_tei_(original_normalized_deposi...
# 138  dep_839095r064_tei_(original_normalized_deposi...
# 634  dep_839096r065_tei_(original_normalized_deposi...
# 127  dep_839098r066_tei_(original_normalized_deposi...
# 134  dep_839099r067_tei_(original_normalized_deposi...
# 379  dep_839102r069_tei_(original_normalized_deposi...
# 29   dep_839103r070_tei_(original_normalized_deposi...
# 93   dep_839105r072_tei_(original_normalized_deposi...
# 117  dep_839104r071_tei_(original_normalized_deposi...
# 186  dep_839106r073_tei_(original_normalized_deposi...
# 161  dep_839118r080_tei_(original_normalized_deposi...
# 169  dep_839122r082_tei_(original_normalized_deposi...
# 133  dep_839123r083_tei_(original_normalized_deposi...
# 19   dep_839124r084_tei_(original_normalized_deposi...
# 16   dep_839125r085_tei_(original_normalized_deposi...
# 16   dep_839125v086_tei_(original_normalized_deposi...
# 16   dep_839126v087_tei_(original_normalized_deposi...
# 16   dep_839127v088_tei_(original_normalized_deposi...
# 40   dep_839132r091_tei_(original_normalized_deposi...
# 341  dep_839136r094_tei_(original_normalized_deposi...
# 120  dep_839141r097_tei_(original_normalized_deposi...
# 29   dep_839143v099_tei_(original_normalized_deposi...
# 43   dep_839143v100_tei_(original_normalized_deposi...
# 226  dep_839145r101_tei_(original_normalized_deposi...
# 576  dep_839147r102_tei_(original_normalized_deposi...
# 126  dep_839149r103_tei_(original_normalized_deposi...
#
#                                          tag location attr_name  \
# 168  {http://www.tei-c.org/ns/1.0}listPerson   header      type
# 231  {http://www.tei-c.org/ns/1.0}listPerson   header      type
# 113  {http://www.tei-c.org/ns/1.0}listPerson   header      type
# 118  {http://www.tei-c.org/ns/1.0}listPerson   header      type
# 116  {http://www.tei-c.org/ns/1.0}listPerson   header      type
# 122  {http://www.tei-c.org/ns/1.0}listPerson   header      type
# 133  {http://www.tei-c.org/ns/1.0}listPerson   header      type
# 227  {http://www.tei-c.org/ns/1.0}listPerson   header      type
# 137  {http://www.tei-c.org/ns/1.0}listPerson   header      type
# 194  {http://www.tei-c.org/ns/1.0}listPerson   header      type
# 188  {http://www.tei-c.org/ns/1.0}listPerson   header      type
# 129  {http://www.tei-c.org/ns/1.0}listPerson   header      type
# 176  {http://www.tei-c.org/ns/1.0}listPerson   header      type
# 152  {http://www.tei-c.org/ns/1.0}listPerson   header      type
# 116  {http://www.tei-c.org/ns/1.0}listPerson   header      type
# 187  {http://www.tei-c.org/ns/1.0}listPerson   header      type
# 163  {http://www.tei-c.org/ns/1.0}listPerson   header      type
# 178  {http://www.tei-c.org/ns/1.0}listPerson   header      type
# 19   {http://www.tei-c.org/ns/1.0}listPerson   header      type
# 138  {http://www.tei-c.org/ns/1.0}listPerson   header      type
# 634  {http://www.tei-c.org/ns/1.0}listPerson   header      type
# 127  {http://www.tei-c.org/ns/1.0}listPerson   header      type
# 134  {http://www.tei-c.org/ns/1.0}listPerson   header      type
# 379  {http://www.tei-c.org/ns/1.0}listPerson   header      type
# 29   {http://www.tei-c.org/ns/1.0}listPerson   header      type
# 93   {http://www.tei-c.org/ns/1.0}listPerson   header      type
# 117  {http://www.tei-c.org/ns/1.0}listPerson   header      type
# 186  {http://www.tei-c.org/ns/1.0}listPerson   header      type
# 161  {http://www.tei-c.org/ns/1.0}listPerson   header      type
# 169  {http://www.tei-c.org/ns/1.0}listPerson   header      type
# 133  {http://www.tei-c.org/ns/1.0}listPerson   header      type
# 19   {http://www.tei-c.org/ns/1.0}listPerson   header      type
# 16   {http://www.tei-c.org/ns/1.0}listPerson   header      type
# 16   {http://www.tei-c.org/ns/1.0}listPerson   header      type
# 16   {http://www.tei-c.org/ns/1.0}listPerson   header      type
# 16   {http://www.tei-c.org/ns/1.0}listPerson   header      type
# 40   {http://www.tei-c.org/ns/1.0}listPerson   header      type
# 341  {http://www.tei-c.org/ns/1.0}listPerson   header      type
# 120  {http://www.tei-c.org/ns/1.0}listPerson   header      type
# 29   {http://www.tei-c.org/ns/1.0}listPerson   header      type
# 43   {http://www.tei-c.org/ns/1.0}listPerson   header      type
# 226  {http://www.tei-c.org/ns/1.0}listPerson   header      type
# 576  {http://www.tei-c.org/ns/1.0}listPerson   header      type
# 126  {http://www.tei-c.org/ns/1.0}listPerson   header      type
#
#                attr_value
# 168  PROVIDEDH Annotators
# 231  PROVIDEDH Annotators
# 113  PROVIDEDH Annotators
# 118  PROVIDEDH Annotators
# 116  PROVIDEDH Annotators
# 122  PROVIDEDH Annotators
# 133  PROVIDEDH Annotators
# 227  PROVIDEDH Annotators
# 137  PROVIDEDH Annotators
# 194  PROVIDEDH Annotators
# 188  PROVIDEDH Annotators
# 129  PROVIDEDH Annotators
# 176  PROVIDEDH Annotators
# 152  PROVIDEDH Annotators
# 116  PROVIDEDH Annotators
# 187  PROVIDEDH Annotators
# 163  PROVIDEDH Annotators
# 178  PROVIDEDH Annotators
# 19   PROVIDEDH Annotators
# 138  PROVIDEDH Annotators
# 634  PROVIDEDH Annotators
# 127  PROVIDEDH Annotators
# 134  PROVIDEDH Annotators
# 379  PROVIDEDH Annotators
# 29   PROVIDEDH Annotators
# 93   PROVIDEDH Annotators
# 117  PROVIDEDH Annotators
# 186  PROVIDEDH Annotators
# 161  PROVIDEDH Annotators
# 169  PROVIDEDH Annotators
# 133  PROVIDEDH Annotators
# 19   PROVIDEDH Annotators
# 16   PROVIDEDH Annotators
# 16   PROVIDEDH Annotators
# 16   PROVIDEDH Annotators
# 16   PROVIDEDH Annotators
# 40   PROVIDEDH Annotators
# 341  PROVIDEDH Annotators
# 120  PROVIDEDH Annotators
# 29   PROVIDEDH Annotators
# 43   PROVIDEDH Annotators
# 226  PROVIDEDH Annotators
# 576  PROVIDEDH Annotators
# 126  PROVIDEDH Annotators
#
#
#                                               document  \
# 213  dep_839064r043_tei_(original_normalized_deposi...
# 222  dep_839064r043_tei_(original_normalized_deposi...
# 226  dep_839064r043_tei_(original_normalized_deposi...
# 231  dep_839064r043_tei_(original_normalized_deposi...
# 150  dep_839066r044_tei_(original_normalized_deposi...
# ..                                                 ...
# 686  dep_839147r102_tei_(original_normalized_deposi...
# 736  dep_839147r102_tei_(original_normalized_deposi...
# 751  dep_839147r102_tei_(original_normalized_deposi...
# 754  dep_839147r102_tei_(original_normalized_deposi...
# 759  dep_839147r102_tei_(original_normalized_deposi...
#
#                                    tag location attr_name  attr_value
# 213  {http://www.tei-c.org/ns/1.0}note     body      type  marginalia
# 222  {http://www.tei-c.org/ns/1.0}note     body      type  marginalia
# 226  {http://www.tei-c.org/ns/1.0}note     body      type  marginalia
# 231  {http://www.tei-c.org/ns/1.0}note     body      type  marginalia
# 150  {http://www.tei-c.org/ns/1.0}note     body      type  marginalia
# ..                                 ...      ...       ...         ...
# 686  {http://www.tei-c.org/ns/1.0}note     body      type  marginalia
# 736  {http://www.tei-c.org/ns/1.0}note     body      type  marginalia
# 751  {http://www.tei-c.org/ns/1.0}note     body      type  marginalia
# 754  {http://www.tei-c.org/ns/1.0}note     body      type  marginalia
# 759  {http://www.tei-c.org/ns/1.0}note     body      type  marginalia
#
# [158 rows x 5 columns]
#
#
#                                               document  \
# 135  dep_839068r046_tei_(original_normalized_deposi...
# 163  dep_839068r046_tei_(original_normalized_deposi...
# 196  dep_839068r046_tei_(original_normalized_deposi...
# 152  dep_839070r047_tei_(original_normalized_deposi...
# 195  dep_839070r047_tei_(original_normalized_deposi...
# 233  dep_839070r047_tei_(original_normalized_deposi...
# 149  dep_839072r048_tei_(original_normalized_deposi...
# 150  dep_839072r048_tei_(original_normalized_deposi...
# 152  dep_839072r048_tei_(original_normalized_deposi...
# 176  dep_839072r048_tei_(original_normalized_deposi...
# 177  dep_839072r048_tei_(original_normalized_deposi...
# 179  dep_839072r048_tei_(original_normalized_deposi...
# 206  dep_839072r048_tei_(original_normalized_deposi...
# 207  dep_839072r048_tei_(original_normalized_deposi...
# 208  dep_839072r048_tei_(original_normalized_deposi...
# 241  dep_839074r049_tei_(original_normalized_deposi...
# 280  dep_839074r049_tei_(original_normalized_deposi...
# 336  dep_839074r049_tei_(original_normalized_deposi...
# 651  dep_839096r065_tei_(original_normalized_deposi...
# 660  dep_839096r065_tei_(original_normalized_deposi...
# 716  dep_839096r065_tei_(original_normalized_deposi...
# 753  dep_839096r065_tei_(original_normalized_deposi...
# 865  dep_839096r065_tei_(original_normalized_deposi...
# 901  dep_839096r065_tei_(original_normalized_deposi...
# 148  dep_839149r103_tei_(original_normalized_deposi...
# 170  dep_839149r103_tei_(original_normalized_deposi...
#
#                                            tag location  \
# 135  {http://www.tei-c.org/ns/1.0}organization     body
# 163  {http://www.tei-c.org/ns/1.0}organization     body
# 196  {http://www.tei-c.org/ns/1.0}organization     body
# 152  {http://www.tei-c.org/ns/1.0}organization     body
# 195  {http://www.tei-c.org/ns/1.0}organization     body
# 233  {http://www.tei-c.org/ns/1.0}organization     body
# 149  {http://www.tei-c.org/ns/1.0}organization     body
# 150  {http://www.tei-c.org/ns/1.0}organization     body
# 152  {http://www.tei-c.org/ns/1.0}organization     body
# 176  {http://www.tei-c.org/ns/1.0}organization     body
# 177  {http://www.tei-c.org/ns/1.0}organization     body
# 179  {http://www.tei-c.org/ns/1.0}organization     body
# 206  {http://www.tei-c.org/ns/1.0}organization     body
# 207  {http://www.tei-c.org/ns/1.0}organization     body
# 208  {http://www.tei-c.org/ns/1.0}organization     body
# 241  {http://www.tei-c.org/ns/1.0}organization     body
# 280  {http://www.tei-c.org/ns/1.0}organization     body
# 336  {http://www.tei-c.org/ns/1.0}organization     body
# 651  {http://www.tei-c.org/ns/1.0}organization     body
# 660  {http://www.tei-c.org/ns/1.0}organization     body
# 716  {http://www.tei-c.org/ns/1.0}organization     body
# 753  {http://www.tei-c.org/ns/1.0}organization     body
# 865  {http://www.tei-c.org/ns/1.0}organization     body
# 901  {http://www.tei-c.org/ns/1.0}organization     body
# 148  {http://www.tei-c.org/ns/1.0}organization     body
# 170  {http://www.tei-c.org/ns/1.0}organization     body
#
#                                     attr_name          attr_value
# 135  {http://www.w3.org/XML/1998/namespace}id  m_organization0324
# 163  {http://www.w3.org/XML/1998/namespace}id  m_organization0325
# 196  {http://www.w3.org/XML/1998/namespace}id  m_organization0326
# 152  {http://www.w3.org/XML/1998/namespace}id  m_organization0321
# 195  {http://www.w3.org/XML/1998/namespace}id  m_organization0322
# 233  {http://www.w3.org/XML/1998/namespace}id  m_organization0323
# 149  {http://www.w3.org/XML/1998/namespace}id  m_organization0315
# 150  {http://www.w3.org/XML/1998/namespace}id  m_organization0316
# 152  {http://www.w3.org/XML/1998/namespace}id  m_organization0317
# 176  {http://www.w3.org/XML/1998/namespace}id  m_organization0318
# 177  {http://www.w3.org/XML/1998/namespace}id  m_organization0319
# 179  {http://www.w3.org/XML/1998/namespace}id  m_organization0320
# 206  {http://www.w3.org/XML/1998/namespace}id  m_organization0321
# 207  {http://www.w3.org/XML/1998/namespace}id  m_organization0322
# 208  {http://www.w3.org/XML/1998/namespace}id  m_organization0323
# 241  {http://www.w3.org/XML/1998/namespace}id  m_organization0304
# 280  {http://www.w3.org/XML/1998/namespace}id  m_organization0305
# 336  {http://www.w3.org/XML/1998/namespace}id  m_organization0306
# 651  {http://www.w3.org/XML/1998/namespace}id  m_organization0319
# 660  {http://www.w3.org/XML/1998/namespace}id  m_organization0320
# 716  {http://www.w3.org/XML/1998/namespace}id  m_organization0321
# 753  {http://www.w3.org/XML/1998/namespace}id  m_organization0322
# 865  {http://www.w3.org/XML/1998/namespace}id  m_organization0323
# 901  {http://www.w3.org/XML/1998/namespace}id  m_organization0324
# 148  {http://www.w3.org/XML/1998/namespace}id  m_organization0392
# 170  {http://www.w3.org/XML/1998/namespace}id  m_organization0393
#
#
#                                               document  \
# 176  dep_839064r043_tei_(original_normalized_deposi...
# 197  dep_839064r043_tei_(original_normalized_deposi...
# 198  dep_839064r043_tei_(original_normalized_deposi...
# 200  dep_839064r043_tei_(original_normalized_deposi...
# 243  dep_839064r043_tei_(original_normalized_deposi...
# ..                                                 ...
# 154  dep_839149r103_tei_(original_normalized_deposi...
# 162  dep_839149r103_tei_(original_normalized_deposi...
# 163  dep_839149r103_tei_(original_normalized_deposi...
# 174  dep_839149r103_tei_(original_normalized_deposi...
# 175  dep_839149r103_tei_(original_normalized_deposi...
#
#                                  tag location attr_name attr_value
# 176  {http://www.tei-c.org/ns/1.0}pb     body         n   fol. 64r
# 197  {http://www.tei-c.org/ns/1.0}pb     body         n   fol. 65r
# 198  {http://www.tei-c.org/ns/1.0}pb     body         n   fol. 65v
# 200  {http://www.tei-c.org/ns/1.0}pb     body         n   fol. 64r
# 243  {http://www.tei-c.org/ns/1.0}pb     body         n   fol. 65v
# ..                               ...      ...       ...        ...
# 154  {http://www.tei-c.org/ns/1.0}pb     body   pagenum       3369
# 162  {http://www.tei-c.org/ns/1.0}pb     body         n  fol. 149r
# 163  {http://www.tei-c.org/ns/1.0}pb     body   pagenum       3368
# 174  {http://www.tei-c.org/ns/1.0}pb     body         n  fol. 149v
# 175  {http://www.tei-c.org/ns/1.0}pb     body   pagenum       3369
#
# [587 rows x 5 columns]
#
#
#                                               document  \
# 142  dep_839064r043_tei_(original_normalized_deposi...
# 143  dep_839064r043_tei_(original_normalized_deposi...
# 147  dep_839064r043_tei_(original_normalized_deposi...
# 148  dep_839064r043_tei_(original_normalized_deposi...
# 150  dep_839064r043_tei_(original_normalized_deposi...
# ..                                                 ...
# 155  dep_839149r103_tei_(original_normalized_deposi...
# 159  dep_839149r103_tei_(original_normalized_deposi...
# 169  dep_839149r103_tei_(original_normalized_deposi...
# 172  dep_839149r103_tei_(original_normalized_deposi...
# 176  dep_839149r103_tei_(original_normalized_deposi...
#
# ...
# 442  dep_839136r094_tei_(original_normalized_deposi...
#
#                                         tag location  \
# 116  {http://www.tei-c.org/ns/1.0}placename   header
# 140  {http://www.tei-c.org/ns/1.0}placename   header
# 652  {http://www.tei-c.org/ns/1.0}placename     body
# 676  {http://www.tei-c.org/ns/1.0}placename     body
# 683  {http://www.tei-c.org/ns/1.0}placename     body
# 723  {http://www.tei-c.org/ns/1.0}placename     body
# 799  {http://www.tei-c.org/ns/1.0}placename     body
# 944  {http://www.tei-c.org/ns/1.0}placename     body
# 382  {http://www.tei-c.org/ns/1.0}placename   header
# 164  {http://www.tei-c.org/ns/1.0}placename   header
# 175  {http://www.tei-c.org/ns/1.0}placename     body
# 177  {http://www.tei-c.org/ns/1.0}placename     body
# 200  {http://www.tei-c.org/ns/1.0}placename     body
# 205  {http://www.tei-c.org/ns/1.0}placename     body
# 369  {http://www.tei-c.org/ns/1.0}placename     body
# 442  {http://www.tei-c.org/ns/1.0}placename     body
#
#                                     attr_name       attr_value
# 116                                      type        Placename
# 140                                      type        Placename
# 652  {http://www.w3.org/XML/1998/namespace}id  m_placename0028
# 676  {http://www.w3.org/XML/1998/namespace}id  m_placename0029
# 683  {http://www.w3.org/XML/1998/namespace}id  m_placename0030
# 723  {http://www.w3.org/XML/1998/namespace}id  m_placename0031
# 799  {http://www.w3.org/XML/1998/namespace}id  m_placename0032
# 944  {http://www.w3.org/XML/1998/namespace}id  m_placename0033
# 382                                      type             City
# 164                                      type        Placename
# 175  {http://www.w3.org/XML/1998/namespace}id  m_placename0025
# 177  {http://www.w3.org/XML/1998/namespace}id  m_placename0026
# 200  {http://www.w3.org/XML/1998/namespace}id  m_placename0027
# 205  {http://www.w3.org/XML/1998/namespace}id  m_placename0028
# 369  {http://www.w3.org/XML/1998/namespace}id  m_placename0025
# 442  {http://www.w3.org/XML/1998/namespace}id  m_placename0026
#
#
#                                               document  \
# 145  dep_839064r043_tei_(original_normalized_deposi...
# 223  dep_839060r041_tei_(original_normalized_deposi...
# 74   dep_839066r044_tei_(original_normalized_deposi...
# 92   dep_839066r045_tei_(original_normalized_deposi...
# 107  dep_839068r046_tei_(original_normalized_deposi...
# 98   dep_839070r047_tei_(original_normalized_deposi...
# 107  dep_839072r048_tei_(original_normalized_deposi...
# 203  dep_839074r049_tei_(original_normalized_deposi...
# 116  dep_839080r052_tei_(original_normalized_deposi...
# 170  dep_839082r053_tei_(original_normalized_deposi...
# 179  dep_839084r054_tei_(original_normalized_deposi...
# 120  dep_839085r055_tei_(original_normalized_deposi...
# 164  dep_839085r056_tei_(original_normalized_deposi...
# 146  dep_839085v057_tei_(original_normalized_deposi...
# 110  dep_839085v058_tei_(original_normalized_deposi...
# 172  dep_839087r059_tei_(original_normalized_deposi...
# 148  dep_839088r060_tei_(original_normalized_deposi...
# 163  dep_839090r061_tei_(original_normalized_deposi...
# 124  dep_839095r064_tei_(original_normalized_deposi...
# 584  dep_839096r065_tei_(original_normalized_deposi...
# 110  dep_839098r066_tei_(original_normalized_deposi...
# 114  dep_839099r067_tei_(original_normalized_deposi...
# 338  dep_839102r069_tei_(original_normalized_deposi...
# 24   dep_839103r070_tei_(original_normalized_deposi...
# 88   dep_839105r072_tei_(original_normalized_deposi...
# 112  dep_839104r071_tei_(original_normalized_deposi...
# 151  dep_839106r073_tei_(original_normalized_deposi...
# 132  dep_839118r080_tei_(original_normalized_deposi...
# 124  dep_839122r082_tei_(original_normalized_deposi...
# 89   dep_839123r083_tei_(original_normalized_deposi...
# 321  dep_839136r094_tei_(original_normalized_deposi...
# 82   dep_839141r097_tei_(original_normalized_deposi...
# 24   dep_839143v099_tei_(original_normalized_deposi...
# 32   dep_839143v100_tei_(original_normalized_deposi...
# 499  dep_839147r102_tei_(original_normalized_deposi...
# 114  dep_839149r103_tei_(original_normalized_deposi...
#
#                                      tag location attr_name attr_value
# 145  {http://www.tei-c.org/ns/1.0}region   header      type     County
# 223  {http://www.tei-c.org/ns/1.0}region   header      type     County
# 74   {http://www.tei-c.org/ns/1.0}region   header      type     County
# 92   {http://www.tei-c.org/ns/1.0}region   header      type     County
# 107  {http://www.tei-c.org/ns/1.0}region   header      type     County
# 98   {http://www.tei-c.org/ns/1.0}region   header      type     County
# 107  {http://www.tei-c.org/ns/1.0}region   header      type     County
# 203  {http://www.tei-c.org/ns/1.0}region   header      type     County
# 116  {http://www.tei-c.org/ns/1.0}region   header      type     County
# 170  {http://www.tei-c.org/ns/1.0}region   header      type     County
# 179  {http://www.tei-c.org/ns/1.0}region   header      type     County
# 120  {http://www.tei-c.org/ns/1.0}region   header      type     County
# 164  {http://www.tei-c.org/ns/1.0}region   header      type     County
# 146  {http://www.tei-c.org/ns/1.0}region   header      type     County
# 110  {http://www.tei-c.org/ns/1.0}region   header      type     County
# 172  {http://www.tei-c.org/ns/1.0}region   header      type     County
# 148  {http://www.tei-c.org/ns/1.0}region   header      type     County
# 163  {http://www.tei-c.org/ns/1.0}region   header      type     County
# 124  {http://www.tei-c.org/ns/1.0}region   header      type     County
# 584  {http://www.tei-c.org/ns/1.0}region   header      type     County
# 110  {http://www.tei-c.org/ns/1.0}region   header      type     County
# 114  {http://www.tei-c.org/ns/1.0}region   header      type     County
# 338  {http://www.tei-c.org/ns/1.0}region   header      type     County
# 24   {http://www.tei-c.org/ns/1.0}region   header      type     County
# 88   {http://www.tei-c.org/ns/1.0}region   header      type     County
# 112  {http://www.tei-c.org/ns/1.0}region   header      type     County
# 151  {http://www.tei-c.org/ns/1.0}region   header      type     County
# 132  {http://www.tei-c.org/ns/1.0}region   header      type     County
# 124  {http://www.tei-c.org/ns/1.0}region   header      type     County
# 89   {http://www.tei-c.org/ns/1.0}region   header      type     County
# 321  {http://www.tei-c.org/ns/1.0}region   header      type     County
# 82   {http://www.tei-c.org/ns/1.0}region   header      type     County
# 24   {http://www.tei-c.org/ns/1.0}region   header      type     County
# 32   {http://www.tei-c.org/ns/1.0}region   header      type     County
# 499  {http://www.tei-c.org/ns/1.0}region   header      type     County
# 114  {http://www.tei-c.org/ns/1.0}region   header      type     County
#
#
#                                               document  \
# 144  dep_839064r043_tei_(original_normalized_deposi...
# 149  dep_839064r043_tei_(original_normalized_deposi...
# 152  dep_839064r043_tei_(original_normalized_deposi...
# 155  dep_839064r043_tei_(original_normalized_deposi...
# 158  dep_839064r043_tei_(original_normalized_deposi...
# ..                                                 ...
# 118  dep_839149r103_tei_(original_normalized_deposi...
# 122  dep_839149r103_tei_(original_normalized_deposi...
# 125  dep_839149r103_tei_(original_normalized_deposi...
# 131  dep_839149r103_tei_(original_normalized_deposi...
# 160  dep_839149r103_tei_(original_normalized_deposi...
#
#                                        tag location attr_name    attr_value
# 144  {http://www.tei-c.org/ns/1.0}roleName   header      type      Deponent
# 149  {http://www.tei-c.org/ns/1.0}roleName   header      type      Deponent
# 152  {http://www.tei-c.org/ns/1.0}roleName   header      type     Mentioned
# 155  {http://www.tei-c.org/ns/1.0}roleName   header      type     Mentioned
# 158  {http://www.tei-c.org/ns/1.0}roleName   header      type     Mentioned
# ..                                     ...      ...       ...           ...
# 118  {http://www.tei-c.org/ns/1.0}roleName   header      type     Mentioned
# 122  {http://www.tei-c.org/ns/1.0}roleName   header      type         Rebel
# 125  {http://www.tei-c.org/ns/1.0}roleName   header      type     Mentioned
# 131  {http://www.tei-c.org/ns/1.0}roleName     body      type  Commissioner
# 160  {http://www.tei-c.org/ns/1.0}roleName     body      type  Commissioner
#
# [425 rows x 5 columns]
#
#
#                                               document  \
# 247  dep_839064r043_tei_(original_normalized_deposi...
# 248  dep_839064r043_tei_(original_normalized_deposi...
# 249  dep_839064r043_tei_(original_normalized_deposi...
# 329  dep_839060r041_tei_(original_normalized_deposi...
# 188  dep_839066r044_tei_(original_normalized_deposi...
# ..                                                 ...
# 100  dep_839143v100_tei_(original_normalized_deposi...
# 101  dep_839143v100_tei_(original_normalized_deposi...
# 788  dep_839147r102_tei_(original_normalized_deposi...
# 789  dep_839147r102_tei_(original_normalized_deposi...
# 180  dep_839149r103_tei_(original_normalized_deposi...
#
#                                        tag location attr_name    attr_value
# 247  {http://www.tei-c.org/ns/1.0}rolename     body      type  commissioner
# 248  {http://www.tei-c.org/ns/1.0}rolename     body      type  commissioner
# 249  {http://www.tei-c.org/ns/1.0}rolename     body      type  commissioner
# 329  {http://www.tei-c.org/ns/1.0}rolename     body      type  commissioner
# 188  {http://www.tei-c.org/ns/1.0}rolename     body      type  commissioner
# ..                                     ...      ...       ...           ...
# 100  {http://www.tei-c.org/ns/1.0}rolename     body      type  commissioner
# 101  {http://www.tei-c.org/ns/1.0}rolename     body      type  commissioner
# 788  {http://www.tei-c.org/ns/1.0}rolename     body      type  commissioner
# 789  {http://www.tei-c.org/ns/1.0}rolename     body      type  commissioner
# 180  {http://www.tei-c.org/ns/1.0}rolename     body      type  commissioner
#
# [74 rows x 5 columns]
#
#
#                                               document  \
# 78   dep_839066r044_tei_(original_normalized_deposi...
# 111  dep_839068r046_tei_(original_normalized_deposi...
# 102  dep_839070r047_tei_(original_normalized_deposi...
# 207  dep_839074r049_tei_(original_normalized_deposi...
# 132  dep_839080r052_tei_(original_normalized_deposi...
# 180  dep_839082r053_tei_(original_normalized_deposi...
# 183  dep_839084r054_tei_(original_normalized_deposi...
# 124  dep_839085r055_tei_(original_normalized_deposi...
# 168  dep_839085r056_tei_(original_normalized_deposi...
# 150  dep_839085v057_tei_(original_normalized_deposi...
# 114  dep_839085v058_tei_(original_normalized_deposi...
# 176  dep_839087r059_tei_(original_normalized_deposi...
# 152  dep_839088r060_tei_(original_normalized_deposi...
# 167  dep_839090r061_tei_(original_normalized_deposi...
# 128  dep_839122r082_tei_(original_normalized_deposi...
# 121  dep_839149r103_tei_(original_normalized_deposi...
#
#                                       tag location attr_name attr_value
# 78   {http://www.tei-c.org/ns/1.0}surname   header      type   Patronym
# 111  {http://www.tei-c.org/ns/1.0}surname   header      type   Patronym
# 102  {http://www.tei-c.org/ns/1.0}surname   header      type   Patronym
# 207  {http://www.tei-c.org/ns/1.0}surname   header      type   Patronym
# 132  {http://www.tei-c.org/ns/1.0}surname   header      type   Patronym
# 180  {http://www.tei-c.org/ns/1.0}surname   header      type   Patronym
# 183  {http://www.tei-c.org/ns/1.0}surname   header      type   Patronym
# 124  {http://www.tei-c.org/ns/1.0}surname   header      type   Patronym
# 168  {http://www.tei-c.org/ns/1.0}surname   header      type   Patronym
# 150  {http://www.tei-c.org/ns/1.0}surname   header      type   Patronym
# 114  {http://www.tei-c.org/ns/1.0}surname   header      type   Patronym
# 176  {http://www.tei-c.org/ns/1.0}surname   header      type   Patronym
# 152  {http://www.tei-c.org/ns/1.0}surname   header      type   Patronym
# 167  {http://www.tei-c.org/ns/1.0}surname   header      type   Patronym
# 128  {http://www.tei-c.org/ns/1.0}surname   header      type   Patronym
# 121  {http://www.tei-c.org/ns/1.0}surname   header      type   Patronym
#
#
#                                               document  \
# 201  dep_839064r043_tei_(original_normalized_deposi...
# 215  dep_839064r043_tei_(original_normalized_deposi...
# 229  dep_839064r043_tei_(original_normalized_deposi...
# 238  dep_839064r043_tei_(original_normalized_deposi...
# 239  dep_839064r043_tei_(original_normalized_deposi...
# ..                                                 ...
# 756  dep_839147r102_tei_(original_normalized_deposi...
# 152  dep_839149r103_tei_(original_normalized_deposi...
# 156  dep_839149r103_tei_(original_normalized_deposi...
# 173  dep_839149r103_tei_(original_normalized_deposi...
# 177  dep_839149r103_tei_(original_normalized_deposi...
#
#                                       tag location attr_name attr_value
# 201  {http://www.tei-c.org/ns/1.0}unclear     body    reason  illegible
# 215  {http://www.tei-c.org/ns/1.0}unclear     body    reason  illegible
# 229  {http://www.tei-c.org/ns/1.0}unclear     body    reason  illegible
# 238  {http://www.tei-c.org/ns/1.0}unclear     body    reason  illegible
# 239  {http://www.tei-c.org/ns/1.0}unclear     body    reason  illegible
# ..                                    ...      ...       ...        ...
# 756  {http://www.tei-c.org/ns/1.0}unclear     body    reason  illegible
# 152  {http://www.tei-c.org/ns/1.0}unclear     body    reason  illegible
# 156  {http://www.tei-c.org/ns/1.0}unclear     body    reason  illegible
# 173  {http://www.tei-c.org/ns/1.0}unclear     body    reason  illegible
# 177  {http://www.tei-c.org/ns/1.0}unclear     body    reason  illegible
#
# [102 rows x 5 columns]
#
#
#                                              document  \
# 4   dep_839064r043_tei_(original_normalized_deposi...
# 5   dep_839064r043_tei_(original_normalized_deposi...
# 6   dep_839064r043_tei_(original_normalized_deposi...
# 7   dep_839064r043_tei_(original_normalized_deposi...
# 11  dep_839064r043_tei_(original_normalized_deposi...
# ..                                                ...
# 12  dep_839149r103_tei_(original_normalized_deposi...
# 15  dep_839149r103_tei_(original_normalized_deposi...
# 16  dep_839149r103_tei_(original_normalized_deposi...
# 17  dep_839149r103_tei_(original_normalized_deposi...
# 18  dep_839149r103_tei_(original_normalized_deposi...
#
#                                          tag location attr_name  \
# 4   {http://www.w3.org/2001/XInclude}include   header      href
# 5   {http://www.w3.org/2001/XInclude}include   header  xpointer
# 6   {http://www.w3.org/2001/XInclude}include   header      href
# 7   {http://www.w3.org/2001/XInclude}include   header  xpointer
# 11  {http://www.w3.org/2001/XInclude}include   header      href
# ..                                       ...      ...       ...
# 12  {http://www.w3.org/2001/XInclude}include   header  xpointer
# 15  {http://www.w3.org/2001/XInclude}include   header      href
# 16  {http://www.w3.org/2001/XInclude}include   header  xpointer
# 17  {http://www.w3.org/2001/XInclude}include   header      href
# 18  {http://www.w3.org/2001/XInclude}include   header  xpointer
#
#               attr_value
# 4        projectDesc.xml
# 5     id1641-projectDesc
# 6      editorialDecl.xml
# 7   id1641-editorialDecl
# 11          keywords.xml
# ..                   ...
# 12                   dt3
# 15          keywords.xml
# 16                  nod7
# 17          keywords.xml
# 18                  nod8
#
# [456 rows x 5 columns]
